# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/main/C4/W4/ungraded_labs/C4_W4_Lab_3_Sunspots_CNN_RNN_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Predicting Sunspots with Neural Networks
#
# At this point in the course, you should be able to explore different network architectures for forecasting. In the previous weeks, you've used DNNs, RNNs, and CNNs to build these different models. In the final practice lab for this course, you'll try one more configuration and that is a combination of all these types of networks: the data windows will pass through a convolution, followed by stacked LSTMs, followed by stacked dense layers. See if this improves results or you can just opt for simpler models.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %% [markdown]
# ## Utilities

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    ax = plt.axes()
    ax.set_facecolor('None')
    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)
    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# ## Download and Preview the Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Thesis/Datasets
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Thesis/Datasets

# %%
df = pd.read_csv("weekly_sales_data.csv")
# Convert the 'Date' column to datetime type
#df['Date'] = pd.to_datetime(df['Unnamed: 0'])
#df.drop('Unnamed: 0', axis=1, inplace=True)
# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             sales
# Date
# 2014-01-12   2.71
# 2014-01-19   1.25
# 2014-01-26   1.66
# 2014-02-02   0.62
# 2014-02-09   0.01

# %%
'''# Download the Dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
'''
# Out:
# '# Download the Dataset\n!wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv\n'

# %%
# Initialize lists
'''
time_step = []
sales = []
# Open CSV file
with open('./Sunspots.csv') as csvfile:

  # Initialize reader
  reader = csv.reader(csvfile, delimiter=',')

  # Skip the first line
  next(reader)

  # Append row and sunspot number to lists
  for row in reader:
    time_step.append(int(row[0]))
    sunspots.append(float(row[2]))

# Convert lists to numpy arrays
time = np.array(time_step)
series = np.array(sales)
'''
# Parameters
time = np.arange(len(df.index), dtype="float32")
date = df.index
series = df['sales'].values
print(type(series))

# Plot the results
#plot_series(date, series)

# Preview the data
plot_series(time, series, xlabel='Weeks', ylabel='Weektly Sales')
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Split the Dataset

# %%
'''# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]
'''
import math
# Define the split time
split_time = math.floor(len(series) * 3 / 4)

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

print(len(time_train))
print(len(time_valid))
# Out:
# 156
# 52

# %% [markdown]
# ## Prepare Features and Labels

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# As mentioned in the lectures, if your results don't good, you can try tweaking the parameters here and see if the model will learn better.

# %%
# Parameters
window_size = 52
batch_size = 16

shuffle_buffer_size = 1000

# Generate the dataset windows
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# You've seen these layers before and here is how it's looks like when combined.

# %%
'''# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64, kernel_size=5,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[window_size, 1]),
  tf.keras.layers.LSTM(52, return_sequences=True),
  tf.keras.layers.LSTM(52),
  tf.keras.layers.Dense(52, activation="relu"),
  tf.keras.layers.Dense(26, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

 # Print the model summary
model.summary()
'''
# Out:
# '# Build the Model\nmodel = tf.keras.models.Sequential([\n  tf.keras.layers.Conv1D(filters=64, kernel_size=5,\n                      strides=1,\n                      activation="relu",\n                      padding=\'causal\',\n                      input_shape=[window_size, 1]),\n  tf.keras.layers.LSTM(52, return_sequences=True),\n  tf.keras.layers.LSTM(52),\n  tf.keras.layers.Dense(52, activation="relu"),\n  tf.keras.layers.Dense(26, activation="relu"),\n  tf.keras.layers.Dense(1),\n  tf.keras.layers.Lambda(lambda x: x * 400)\n])\n\n # Print the model summary\nmodel.summary()\n'

# %%
l2_regularization = 0.03
dropout_rate = 0.115

# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=16, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[None, 1]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(52, return_sequences=True, dropout=dropout_rate)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(52, kernel_regularizer=tf.keras.regularizers.l2(l2_regularization))),
#  tf.keras.layers.Dense(26, activation="relu"),
#  tf.keras.layers.Dense(13, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100)
])

 # Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 16)          64
#
#  bidirectional (Bidirectiona  (None, None, 104)        28704
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 104)              65312
#  nal)
#
#  dense (Dense)               (None, 1)                 105
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 94,185
# Trainable params: 94,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''# Define the L2 regularization parameter
l1_regularization = 0.005
l2_regularization = 0.005
# Define the dropout rate for LSTM layers
dropout_rate = 0.05

# Build the Model with regularization
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=5,
                           strides=1,
                           activation="relu",
                           padding='causal',
                           input_shape=[window_size, 1]),
    tf.keras.layers.LSTM(52, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(l2_regularization)),
    tf.keras.layers.LSTM(52,  dropout=dropout_rate),
    tf.keras.layers.Dense(52, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(l1_regularization)),
    tf.keras.layers.Dense(26, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(l2_regularization)),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100.0) # range of number
])

# Print the model summary
model.summary()'''
# Out:
# '# Define the L2 regularization parameter\nl1_regularization = 0.005\nl2_regularization = 0.005\n# Define the dropout rate for LSTM layers\ndropout_rate = 0.05\n\n# Build the Model with regularization\nmodel = tf.keras.models.Sequential([\n    tf.keras.layers.Conv1D(filters=64, kernel_size=5,\n                           strides=1,\n                           activation="relu",\n                           padding=\'causal\',\n                           input_shape=[window_size, 1]),\n    tf.keras.layers.LSTM(52, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(l2_regularization)),\n    tf.keras.layers.LSTM(52,  dropout=dropout_rate),\n    tf.keras.layers.Dense(52, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(l1_regularization)),\n    tf.keras.layers.Dense(26, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(l2_regularization)),\n    tf.keras.layers.Dense(1),\n    tf.keras.layers.Lambda(lambda x: x * 100.0) # range of number\n])\n\n# Print the model summary\nmodel.summary()'

# %%
from io import BytesIO
# Create a buffer to save the model summary image
buffer = BytesIO()

# Plot the model summary and save it to a file
tf.keras.utils.plot_model(model, to_file="model_summary.png", show_shapes=True, show_layer_names=True)

# Display the saved image
img = plt.imread("model_summary.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Tune the Learning Rate
#
# As usual, you will want to pick an optimal learning rate.

# %%
# Get initial weights
init_weights = model.get_weights()

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.Adam()

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 7/7 [==============================] - 11s 141ms/step - loss: 12.5977 - lr: 1.0000e-08
# Epoch 2/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.4971 - lr: 1.1220e-08
# Epoch 3/100
# 7/7 [==============================] - 1s 81ms/step - loss: 12.7783 - lr: 1.2589e-08
# Epoch 4/100
# 7/7 [==============================] - 1s 81ms/step - loss: 13.1466 - lr: 1.4125e-08
# Epoch 5/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.7796 - lr: 1.5849e-08
# Epoch 6/100
# 7/7 [==============================] - 1s 86ms/step - loss: 12.4468 - lr: 1.7783e-08
# Epoch 7/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.7999 - lr: 1.9953e-08
# Epoch 8/100
# 7/7 [==============================] - 1s 82ms/step - loss: 12.5184 - lr: 2.2387e-08
# Epoch 9/100
# 7/7 [==============================] - 1s 85ms/step - loss: 12.8236 - lr: 2.5119e-08
# Epoch 10/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.4378 - lr: 2.8184e-08
# Epoch 11/100
# 7/7 [==============================] - 1s 83ms/step - loss: 12.6549 - lr: 3.1623e-08
# Epoch 12/100
# 7/7 [==============================] - 1s 81ms/step - loss: 12.5978 - lr: 3.5481e-08
# Epoch 13/100
# 7/7 [==============================] - 1s 113ms/step - loss: 12.2872 - lr: 3.9811e-08
# Epoch 14/100
# 7/7 [==============================] - 1s 150ms/step - loss: 12.5732 - lr: 4.4668e-08
# Epoch 15/100
# 7/7 [==============================] - 1s 152ms/step - loss: 12.7108 - lr: 5.0119e-08
# Epoch 16/100
# 7/7 [==============================] - 1s 152ms/step - loss: 12.6384 - lr: 5.6234e-08
# Epoch 17/100
# 7/7 [==============================] - 1s 92ms/step - loss: 12.8486 - lr: 6.3096e-08
# Epoch 18/100
# 7/7 [==============================] - 1s 81ms/step - loss: 12.6035 - lr: 7.0795e-08
# Epoch 19/100
# 7/7 [==============================] - 1s 80ms/step - loss: 12.6219 - lr: 7.9433e-08
# Epoch 20/100
# 7/7 [==============================] - 1s 82ms/step - loss: 12.1803 - lr: 8.9125e-08
# Epoch 21/100
# 7/7 [==============================] - 1s 95ms/step - loss: 12.6498 - lr: 1.0000e-07
# Epoch 22/100
# 7/7 [==============================] - 1s 119ms/step - loss: 12.3349 - lr: 1.1220e-07
# Epoch 23/100
# 7/7 [==============================] - 1s 171ms/step - loss: 12.8623 - lr: 1.2589e-07
# Epoch 24/100
# 7/7 [==============================] - 1s 82ms/step - loss: 12.3619 - lr: 1.4125e-07
# Epoch 25/100
# 7/7 [==============================] - 1s 81ms/step - loss: 12.8045 - lr: 1.5849e-07
# Epoch 26/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.7646 - lr: 1.7783e-07
# Epoch 27/100
# 7/7 [==============================] - 1s 81ms/step - loss: 12.6855 - lr: 1.9953e-07
# Epoch 28/100
# 7/7 [==============================] - 1s 121ms/step - loss: 12.2892 - lr: 2.2387e-07
# Epoch 29/100
# 7/7 [==============================] - 1s 153ms/step - loss: 12.0257 - lr: 2.5119e-07
# Epoch 30/100
# 7/7 [==============================] - 1s 152ms/step - loss: 12.5821 - lr: 2.8184e-07
# Epoch 31/100
# 7/7 [==============================] - 1s 151ms/step - loss: 12.3463 - lr: 3.1623e-07
# Epoch 32/100
# 7/7 [==============================] - 1s 82ms/step - loss: 12.6320 - lr: 3.5481e-07
# Epoch 33/100
# 7/7 [==============================] - 1s 83ms/step - loss: 12.0333 - lr: 3.9811e-07
# Epoch 34/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.3660 - lr: 4.4668e-07
# Epoch 35/100
# 7/7 [==============================] - 1s 82ms/step - loss: 12.0179 - lr: 5.0119e-07
# Epoch 36/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.0734 - lr: 5.6234e-07
# Epoch 37/100
# 7/7 [==============================] - 1s 83ms/step - loss: 12.3199 - lr: 6.3096e-07
# Epoch 38/100
# 7/7 [==============================] - 1s 84ms/step - loss: 11.9663 - lr: 7.0795e-07
# Epoch 39/100
# 7/7 [==============================] - 1s 80ms/step - loss: 12.0278 - lr: 7.9433e-07
# Epoch 40/100
# 7/7 [==============================] - 1s 82ms/step - loss: 11.6000 - lr: 8.9125e-07
# Epoch 41/100
# 7/7 [==============================] - 1s 82ms/step - loss: 11.5608 - lr: 1.0000e-06
# Epoch 42/100
# 7/7 [==============================] - 1s 82ms/step - loss: 11.9115 - lr: 1.1220e-06
# Epoch 43/100
# 7/7 [==============================] - 1s 85ms/step - loss: 11.4581 - lr: 1.2589e-06
# Epoch 44/100
# 7/7 [==============================] - 1s 81ms/step - loss: 12.1797 - lr: 1.4125e-06
# Epoch 45/100
# 7/7 [==============================] - 1s 84ms/step - loss: 11.6475 - lr: 1.5849e-06
# Epoch 46/100
# 7/7 [==============================] - 1s 80ms/step - loss: 11.5560 - lr: 1.7783e-06
# Epoch 47/100
# 7/7 [==============================] - 1s 155ms/step - loss: 11.6422 - lr: 1.9953e-06
# Epoch 48/100
# 7/7 [==============================] - 1s 153ms/step - loss: 11.6529 - lr: 2.2387e-06
# Epoch 49/100
# 7/7 [==============================] - 1s 153ms/step - loss: 11.5323 - lr: 2.5119e-06
# Epoch 50/100
# 7/7 [==============================] - 1s 187ms/step - loss: 11.5252 - lr: 2.8184e-06
# Epoch 51/100
# 7/7 [==============================] - 1s 88ms/step - loss: 11.3933 - lr: 3.1623e-06
# Epoch 52/100
# 7/7 [==============================] - 1s 83ms/step - loss: 11.4150 - lr: 3.5481e-06
# Epoch 53/100
# 7/7 [==============================] - 1s 97ms/step - loss: 11.7974 - lr: 3.9811e-06
# Epoch 54/100
# 7/7 [==============================] - 1s 86ms/step - loss: 11.6113 - lr: 4.4668e-06
# Epoch 55/100
# 7/7 [==============================] - 1s 86ms/step - loss: 11.4497 - lr: 5.0119e-06
# Epoch 56/100
# 7/7 [==============================] - 1s 85ms/step - loss: 11.3274 - lr: 5.6234e-06
# Epoch 57/100
# 7/7 [==============================] - 1s 82ms/step - loss: 11.1828 - lr: 6.3096e-06
# Epoch 58/100
# 7/7 [==============================] - 1s 81ms/step - loss: 10.7514 - lr: 7.0795e-06
# Epoch 59/100
# 7/7 [==============================] - 1s 151ms/step - loss: 11.2900 - lr: 7.9433e-06
# Epoch 60/100
# 7/7 [==============================] - 1s 151ms/step - loss: 11.3991 - lr: 8.9125e-06
# Epoch 61/100
# 7/7 [==============================] - 1s 148ms/step - loss: 11.1047 - lr: 1.0000e-05
# Epoch 62/100
# 7/7 [==============================] - 1s 112ms/step - loss: 11.3312 - lr: 1.1220e-05
# Epoch 63/100
# 7/7 [==============================] - 1s 84ms/step - loss: 11.1115 - lr: 1.2589e-05
# Epoch 64/100
# 7/7 [==============================] - 1s 83ms/step - loss: 10.9609 - lr: 1.4125e-05
# Epoch 65/100
# 7/7 [==============================] - 1s 81ms/step - loss: 10.9134 - lr: 1.5849e-05
# Epoch 66/100
# 7/7 [==============================] - 1s 84ms/step - loss: 11.0637 - lr: 1.7783e-05
# Epoch 67/100
# 7/7 [==============================] - 1s 91ms/step - loss: 10.8463 - lr: 1.9953e-05
# Epoch 68/100
# 7/7 [==============================] - 1s 82ms/step - loss: 10.9423 - lr: 2.2387e-05
# Epoch 69/100
# 7/7 [==============================] - 1s 96ms/step - loss: 10.3305 - lr: 2.5119e-05
# Epoch 70/100
# 7/7 [==============================] - 1s 96ms/step - loss: 10.5532 - lr: 2.8184e-05
# Epoch 71/100
# 7/7 [==============================] - 1s 85ms/step - loss: 10.4114 - lr: 3.1623e-05
# Epoch 72/100
# 7/7 [==============================] - 1s 138ms/step - loss: 10.3704 - lr: 3.5481e-05
# Epoch 73/100
# 7/7 [==============================] - 1s 147ms/step - loss: 10.2632 - lr: 3.9811e-05
# Epoch 74/100
# 7/7 [==============================] - 1s 152ms/step - loss: 10.5057 - lr: 4.4668e-05
# Epoch 75/100
# 7/7 [==============================] - 1s 100ms/step - loss: 10.6118 - lr: 5.0119e-05
# Epoch 76/100
# 7/7 [==============================] - 1s 82ms/step - loss: 10.2481 - lr: 5.6234e-05
# Epoch 77/100
# 7/7 [==============================] - 1s 79ms/step - loss: 10.2415 - lr: 6.3096e-05
# Epoch 78/100
# 7/7 [==============================] - 1s 81ms/step - loss: 10.1999 - lr: 7.0795e-05
# Epoch 79/100
# 7/7 [==============================] - 1s 83ms/step - loss: 10.2485 - lr: 7.9433e-05
# Epoch 80/100
# 7/7 [==============================] - 1s 83ms/step - loss: 10.3064 - lr: 8.9125e-05
# Epoch 81/100
# 7/7 [==============================] - 1s 92ms/step - loss: 10.0565 - lr: 1.0000e-04
# Epoch 82/100
# 7/7 [==============================] - 1s 89ms/step - loss: 9.8334 - lr: 1.1220e-04
# Epoch 83/100
# 7/7 [==============================] - 1s 173ms/step - loss: 9.5539 - lr: 1.2589e-04
# Epoch 84/100
# 7/7 [==============================] - 1s 179ms/step - loss: 9.5557 - lr: 1.4125e-04
# Epoch 85/100
# 7/7 [==============================] - 1s 80ms/step - loss: 9.1927 - lr: 1.5849e-04
# Epoch 86/100
# 7/7 [==============================] - 1s 85ms/step - loss: 9.7797 - lr: 1.7783e-04
# Epoch 87/100
# 7/7 [==============================] - 1s 82ms/step - loss: 9.6670 - lr: 1.9953e-04
# Epoch 88/100
# 7/7 [==============================] - 1s 148ms/step - loss: 9.6459 - lr: 2.2387e-04
# Epoch 89/100
# 7/7 [==============================] - 1s 153ms/step - loss: 9.6089 - lr: 2.5119e-04
# Epoch 90/100
# 7/7 [==============================] - 1s 145ms/step - loss: 9.6619 - lr: 2.8184e-04
# Epoch 91/100
# 7/7 [==============================] - 1s 131ms/step - loss: 9.6795 - lr: 3.1623e-04
# Epoch 92/100
# 7/7 [==============================] - 1s 80ms/step - loss: 10.0952 - lr: 3.5481e-04
# Epoch 93/100
# 7/7 [==============================] - 1s 82ms/step - loss: 9.3226 - lr: 3.9811e-04
# Epoch 94/100
# 7/7 [==============================] - 1s 83ms/step - loss: 9.8726 - lr: 4.4668e-04
# Epoch 95/100
# 7/7 [==============================] - 1s 81ms/step - loss: 9.1100 - lr: 5.0119e-04
# Epoch 96/100
# 7/7 [==============================] - 1s 83ms/step - loss: 8.4281 - lr: 5.6234e-04
# Epoch 97/100
# 7/7 [==============================] - 1s 82ms/step - loss: 8.2115 - lr: 6.3096e-04
# Epoch 98/100
# 7/7 [==============================] - 1s 81ms/step - loss: 8.0656 - lr: 7.0795e-04
# Epoch 99/100
# 7/7 [==============================] - 1s 84ms/step - loss: 8.6967 - lr: 7.9433e-04
# Epoch 100/100
# 7/7 [==============================] - 1s 80ms/step - loss: 8.4124 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning Rate vs Loss")
# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 30])
# Out:
# (1e-08, 0.001, 0.0, 30.0)

# %% [markdown]
# ## Train the Model
#
# Now you can proceed to reset and train the model. It is set for 100 epochs in the cell below but feel free to increase it if you want. Laurence got his results in the lectures after 500.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %%
# Set the learning rate
learning_rate = 1e-4

# Set the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Train the model
history = model.fit(train_set,epochs=500)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 11s 19ms/step - loss: 12.0755 - mae: 4.3105
# Epoch 2/500
# 7/7 [==============================] - 0s 15ms/step - loss: 11.2261 - mae: 3.4654
# Epoch 3/500
# 7/7 [==============================] - 0s 14ms/step - loss: 11.2034 - mae: 3.4641
# Epoch 4/500
# 7/7 [==============================] - 0s 14ms/step - loss: 10.8647 - mae: 3.1602
# Epoch 5/500
# 7/7 [==============================] - 0s 14ms/step - loss: 10.5573 - mae: 2.8871
# Epoch 6/500
# 7/7 [==============================] - 0s 14ms/step - loss: 10.4648 - mae: 2.8258
# Epoch 7/500
# 7/7 [==============================] - 0s 15ms/step - loss: 10.1945 - mae: 2.5473
# Epoch 8/500
# 7/7 [==============================] - 0s 13ms/step - loss: 10.1084 - mae: 2.5044
# Epoch 9/500
# 7/7 [==============================] - 0s 15ms/step - loss: 10.3175 - mae: 2.7633
# Epoch 10/500
# 7/7 [==============================] - 0s 13ms/step - loss: 10.2831 - mae: 2.7474
# Epoch 11/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.9718 - mae: 2.4696
# Epoch 12/500
# 7/7 [==============================] - 0s 14ms/step - loss: 10.1383 - mae: 2.6615
# Epoch 13/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.7478 - mae: 2.2887
# Epoch 14/500
# 7/7 [==============================] - 0s 14ms/step - loss: 9.6404 - mae: 2.2302
# Epoch 15/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.5964 - mae: 2.1995
# Epoch 16/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.7460 - mae: 2.3768
# Epoch 17/500
# 7/7 [==============================] - 0s 14ms/step - loss: 9.6091 - mae: 2.2705
# Epoch 18/500
# 7/7 [==============================] - 0s 14ms/step - loss: 9.5525 - mae: 2.2468
# Epoch 19/500
# 7/7 [==============================] - 0s 14ms/step - loss: 9.5374 - mae: 2.2502
# Epoch 20/500
# 7/7 [==============================] - 0s 15ms/step - loss: 9.7772 - mae: 2.5555
# Epoch 21/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.4274 - mae: 2.2298
# Epoch 22/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.4306 - mae: 2.2384
# Epoch 23/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.9677 - mae: 1.7898
# Epoch 24/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.3354 - mae: 2.2193
# Epoch 25/500
# 7/7 [==============================] - 0s 15ms/step - loss: 9.4295 - mae: 2.3433
# Epoch 26/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.3442 - mae: 2.2771
# Epoch 27/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.3228 - mae: 2.2775
# Epoch 28/500
# 7/7 [==============================] - 0s 15ms/step - loss: 8.8923 - mae: 1.8507
# Epoch 29/500
# 7/7 [==============================] - 0s 14ms/step - loss: 9.0800 - mae: 2.0965
# Epoch 30/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.1337 - mae: 2.1643
# Epoch 31/500
# 7/7 [==============================] - 0s 13ms/step - loss: 9.0039 - mae: 2.0573
# Epoch 32/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.6734 - mae: 1.7439
# Epoch 33/500
# 7/7 [==============================] - 0s 17ms/step - loss: 8.9351 - mae: 2.0453
# Epoch 34/500
# 7/7 [==============================] - 0s 14ms/step - loss: 8.7768 - mae: 1.9241
# Epoch 35/500
# 7/7 [==============================] - 0s 15ms/step - loss: 8.8824 - mae: 2.0430
# Epoch 36/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.6704 - mae: 1.8560
# Epoch 37/500
# 7/7 [==============================] - 0s 14ms/step - loss: 8.7178 - mae: 1.9304
# Epoch 38/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.7745 - mae: 2.0107
# Epoch 39/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.7579 - mae: 2.0346
# Epoch 40/500
# 7/7 [==============================] - 0s 14ms/step - loss: 8.5200 - mae: 1.7880
# Epoch 41/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.5658 - mae: 1.8736
# Epoch 42/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.6129 - mae: 1.9448
# Epoch 43/500
# 7/7 [==============================] - 0s 19ms/step - loss: 8.3742 - mae: 1.7246
# Epoch 44/500
# 7/7 [==============================] - 0s 19ms/step - loss: 8.4378 - mae: 1.8286
# Epoch 45/500
# 7/7 [==============================] - 0s 19ms/step - loss: 8.3134 - mae: 1.6979
# Epoch 46/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.3743 - mae: 1.8009
# Epoch 47/500
# 7/7 [==============================] - 0s 20ms/step - loss: 8.5456 - mae: 2.0245
# Epoch 48/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.6836 - mae: 2.1793
# Epoch 49/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.2182 - mae: 1.7246
# Epoch 50/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.2500 - mae: 1.7895
# Epoch 51/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.1305 - mae: 1.6874
# Epoch 52/500
# 7/7 [==============================] - 0s 20ms/step - loss: 8.1729 - mae: 1.7585
# Epoch 53/500
# 7/7 [==============================] - 0s 20ms/step - loss: 8.1362 - mae: 1.7390
# Epoch 54/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.2362 - mae: 1.8849
# Epoch 55/500
# 7/7 [==============================] - 0s 21ms/step - loss: 8.3551 - mae: 2.0123
# Epoch 56/500
# 7/7 [==============================] - 0s 15ms/step - loss: 8.0509 - mae: 1.7208
# Epoch 57/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.0702 - mae: 1.7496
# Epoch 58/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.9855 - mae: 1.7267
# Epoch 59/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.2293 - mae: 1.9940
# Epoch 60/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.9723 - mae: 1.7333
# Epoch 61/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.0292 - mae: 1.8239
# Epoch 62/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.9188 - mae: 1.7429
# Epoch 63/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.8306 - mae: 1.6677
# Epoch 64/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.8667 - mae: 1.7283
# Epoch 65/500
# 7/7 [==============================] - 0s 13ms/step - loss: 8.1236 - mae: 2.0053
# Epoch 66/500
# 7/7 [==============================] - 0s 14ms/step - loss: 8.2919 - mae: 2.1913
# Epoch 67/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.8973 - mae: 1.8149
# Epoch 68/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.7746 - mae: 1.7148
# Epoch 69/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.8576 - mae: 1.8261
# Epoch 70/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.7004 - mae: 1.6705
# Epoch 71/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.6389 - mae: 1.6508
# Epoch 72/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.6039 - mae: 1.6189
# Epoch 73/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.5166 - mae: 1.5501
# Epoch 74/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.6513 - mae: 1.7252
# Epoch 75/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.8513 - mae: 1.9451
# Epoch 76/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.7606 - mae: 1.8814
# Epoch 77/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.4889 - mae: 1.6247
# Epoch 78/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.6585 - mae: 1.8280
# Epoch 79/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.5835 - mae: 1.7675
# Epoch 80/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.4389 - mae: 1.6065
# Epoch 81/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.4226 - mae: 1.6418
# Epoch 82/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.6805 - mae: 1.9378
# Epoch 83/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.7767 - mae: 2.0386
# Epoch 84/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.8532 - mae: 2.1362
# Epoch 85/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.6898 - mae: 1.9790
# Epoch 86/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.6758 - mae: 2.0112
# Epoch 87/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.4655 - mae: 1.7870
# Epoch 88/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.2362 - mae: 1.5667
# Epoch 89/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.2309 - mae: 1.5884
# Epoch 90/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.3208 - mae: 1.7117
# Epoch 91/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.3919 - mae: 1.8058
# Epoch 92/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.1170 - mae: 1.5299
# Epoch 93/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.1802 - mae: 1.6071
# Epoch 94/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.2129 - mae: 1.6719
# Epoch 95/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.1798 - mae: 1.6712
# Epoch 96/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.3302 - mae: 1.8343
# Epoch 97/500
# 7/7 [==============================] - 0s 17ms/step - loss: 7.1027 - mae: 1.6119
# Epoch 98/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.0687 - mae: 1.5912
# Epoch 99/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.1132 - mae: 1.6629
# Epoch 100/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.1607 - mae: 1.7163
# Epoch 101/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.9749 - mae: 1.5401
# Epoch 102/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.1530 - mae: 1.7497
# Epoch 103/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.1520 - mae: 1.7961
# Epoch 104/500
# 7/7 [==============================] - 0s 15ms/step - loss: 7.0654 - mae: 1.6984
# Epoch 105/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.0231 - mae: 1.6901
# Epoch 106/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.0068 - mae: 1.6643
# Epoch 107/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.0377 - mae: 1.7266
# Epoch 108/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.8349 - mae: 1.5274
# Epoch 109/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.8338 - mae: 1.5548
# Epoch 110/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.9065 - mae: 1.6382
# Epoch 111/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.8560 - mae: 1.6161
# Epoch 112/500
# 7/7 [==============================] - 0s 15ms/step - loss: 6.7274 - mae: 1.4749
# Epoch 113/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.9534 - mae: 1.7434
# Epoch 114/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.9495 - mae: 1.7460
# Epoch 115/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.6703 - mae: 1.4671
# Epoch 116/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.9575 - mae: 1.7900
# Epoch 117/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.7874 - mae: 1.6467
# Epoch 118/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.8990 - mae: 1.7810
# Epoch 119/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.8506 - mae: 1.7337
# Epoch 120/500
# 7/7 [==============================] - 0s 14ms/step - loss: 7.0045 - mae: 1.9075
# Epoch 121/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.9299 - mae: 1.8559
# Epoch 122/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.8754 - mae: 1.8242
# Epoch 123/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.6694 - mae: 1.6022
# Epoch 124/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.6194 - mae: 1.5796
# Epoch 125/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.5733 - mae: 1.5350
# Epoch 126/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.5055 - mae: 1.4641
# Epoch 127/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.5215 - mae: 1.5029
# Epoch 128/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.5804 - mae: 1.5717
# Epoch 129/500
# 7/7 [==============================] - 0s 22ms/step - loss: 6.6025 - mae: 1.6423
# Epoch 130/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.6022 - mae: 1.6498
# Epoch 131/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.5029 - mae: 1.5520
# Epoch 132/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.4874 - mae: 1.5563
# Epoch 133/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.4231 - mae: 1.5124
# Epoch 134/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.3741 - mae: 1.4506
# Epoch 135/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.2968 - mae: 1.4003
# Epoch 136/500
# 7/7 [==============================] - 0s 19ms/step - loss: 6.4011 - mae: 1.5158
# Epoch 137/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.5150 - mae: 1.6832
# Epoch 138/500
# 7/7 [==============================] - 0s 23ms/step - loss: 6.2864 - mae: 1.4218
# Epoch 139/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.3958 - mae: 1.5722
# Epoch 140/500
# 7/7 [==============================] - 0s 20ms/step - loss: 6.3804 - mae: 1.5675
# Epoch 141/500
# 7/7 [==============================] - 0s 20ms/step - loss: 6.3125 - mae: 1.4779
# Epoch 142/500
# 7/7 [==============================] - 0s 16ms/step - loss: 6.4880 - mae: 1.7064
# Epoch 143/500
# 7/7 [==============================] - 0s 15ms/step - loss: 6.6077 - mae: 1.8350
# Epoch 144/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.4017 - mae: 1.6263
# Epoch 145/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.3201 - mae: 1.5687
# Epoch 146/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.5647 - mae: 1.8480
# Epoch 147/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.3925 - mae: 1.6713
# Epoch 148/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.3587 - mae: 1.6387
# Epoch 149/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.2329 - mae: 1.5052
# Epoch 150/500
# 7/7 [==============================] - 0s 15ms/step - loss: 6.1905 - mae: 1.5032
# Epoch 151/500
# 7/7 [==============================] - 0s 15ms/step - loss: 6.1281 - mae: 1.4561
# Epoch 152/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0919 - mae: 1.4265
# Epoch 153/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.1839 - mae: 1.5442
# Epoch 154/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.3173 - mae: 1.6954
# Epoch 155/500
# 7/7 [==============================] - 0s 15ms/step - loss: 6.2202 - mae: 1.5964
# Epoch 156/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.2643 - mae: 1.6567
# Epoch 157/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.1718 - mae: 1.5722
# Epoch 158/500
# 7/7 [==============================] - 0s 15ms/step - loss: 6.2003 - mae: 1.6067
# Epoch 159/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.2202 - mae: 1.6538
# Epoch 160/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.1646 - mae: 1.5965
# Epoch 161/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0279 - mae: 1.4771
# Epoch 162/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.1295 - mae: 1.5994
# Epoch 163/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0103 - mae: 1.4747
# Epoch 164/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.9947 - mae: 1.4667
# Epoch 165/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0402 - mae: 1.5215
# Epoch 166/500
# 7/7 [==============================] - 0s 14ms/step - loss: 6.2448 - mae: 1.7642
# Epoch 167/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.2770 - mae: 1.8256
# Epoch 168/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.9843 - mae: 1.5006
# Epoch 169/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.9449 - mae: 1.4931
# Epoch 170/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.9468 - mae: 1.4758
# Epoch 171/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0160 - mae: 1.5801
# Epoch 172/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.9709 - mae: 1.5547
# Epoch 173/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0611 - mae: 1.6573
# Epoch 174/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.8520 - mae: 1.4428
# Epoch 175/500
# 7/7 [==============================] - 0s 13ms/step - loss: 6.0360 - mae: 1.6566
# Epoch 176/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.8790 - mae: 1.4825
# Epoch 177/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.8795 - mae: 1.4910
# Epoch 178/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.7784 - mae: 1.3846
# Epoch 179/500
# 7/7 [==============================] - 0s 16ms/step - loss: 5.8052 - mae: 1.4737
# Epoch 180/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.7740 - mae: 1.4411
# Epoch 181/500
# 7/7 [==============================] - 0s 16ms/step - loss: 5.8876 - mae: 1.5568
# Epoch 182/500
# 7/7 [==============================] - 0s 16ms/step - loss: 5.9226 - mae: 1.6292
# Epoch 183/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.6945 - mae: 1.3721
# Epoch 184/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7629 - mae: 1.4745
# Epoch 185/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7521 - mae: 1.4823
# Epoch 186/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.7954 - mae: 1.5371
# Epoch 187/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.7763 - mae: 1.5152
# Epoch 188/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.8263 - mae: 1.5845
# Epoch 189/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7349 - mae: 1.4920
# Epoch 190/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6101 - mae: 1.3764
# Epoch 191/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.7486 - mae: 1.5258
# Epoch 192/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.8589 - mae: 1.6498
# Epoch 193/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.8660 - mae: 1.7026
# Epoch 194/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7526 - mae: 1.5850
# Epoch 195/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7841 - mae: 1.6043
# Epoch 196/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6526 - mae: 1.4928
# Epoch 197/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.7921 - mae: 1.6460
# Epoch 198/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6537 - mae: 1.4947
# Epoch 199/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.7105 - mae: 1.5661
# Epoch 200/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6153 - mae: 1.4706
# Epoch 201/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.5466 - mae: 1.4161
# Epoch 202/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6724 - mae: 1.5681
# Epoch 203/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.6009 - mae: 1.5235
# Epoch 204/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7154 - mae: 1.6135
# Epoch 205/500
# 7/7 [==============================] - 0s 17ms/step - loss: 5.6529 - mae: 1.5798
# Epoch 206/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.5126 - mae: 1.4189
# Epoch 207/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.7051 - mae: 1.6380
# Epoch 208/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.6121 - mae: 1.5718
# Epoch 209/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.5321 - mae: 1.5022
# Epoch 210/500
# 7/7 [==============================] - 0s 20ms/step - loss: 5.4954 - mae: 1.4399
# Epoch 211/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.4774 - mae: 1.4530
# Epoch 212/500
# 7/7 [==============================] - 0s 20ms/step - loss: 5.6985 - mae: 1.6852
# Epoch 213/500
# 7/7 [==============================] - 0s 21ms/step - loss: 6.0077 - mae: 2.0473
# Epoch 214/500
# 7/7 [==============================] - 0s 23ms/step - loss: 5.7731 - mae: 1.8094
# Epoch 215/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.7596 - mae: 1.8035
# Epoch 216/500
# 7/7 [==============================] - 0s 22ms/step - loss: 5.4776 - mae: 1.5111
# Epoch 217/500
# 7/7 [==============================] - 0s 22ms/step - loss: 5.5048 - mae: 1.5509
# Epoch 218/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.3861 - mae: 1.4255
# Epoch 219/500
# 7/7 [==============================] - 0s 19ms/step - loss: 5.4875 - mae: 1.5351
# Epoch 220/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.4874 - mae: 1.5538
# Epoch 221/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.3893 - mae: 1.4474
# Epoch 222/500
# 7/7 [==============================] - 0s 20ms/step - loss: 5.2845 - mae: 1.3415
# Epoch 223/500
# 7/7 [==============================] - 0s 20ms/step - loss: 5.3469 - mae: 1.4280
# Epoch 224/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.2802 - mae: 1.3489
# Epoch 225/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.4021 - mae: 1.5070
# Epoch 226/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.4364 - mae: 1.5359
# Epoch 227/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2117 - mae: 1.3179
# Epoch 228/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.4516 - mae: 1.5655
# Epoch 229/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2675 - mae: 1.3714
# Epoch 230/500
# 7/7 [==============================] - 0s 16ms/step - loss: 5.5458 - mae: 1.7037
# Epoch 231/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.5902 - mae: 1.7466
# Epoch 232/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.3646 - mae: 1.5146
# Epoch 233/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2904 - mae: 1.4649
# Epoch 234/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2591 - mae: 1.4212
# Epoch 235/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.4186 - mae: 1.5999
# Epoch 236/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.5313 - mae: 1.7335
# Epoch 237/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2879 - mae: 1.4759
# Epoch 238/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.3465 - mae: 1.5473
# Epoch 239/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.4500 - mae: 1.6891
# Epoch 240/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.4952 - mae: 1.7516
# Epoch 241/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.2005 - mae: 1.4142
# Epoch 242/500
# 7/7 [==============================] - 0s 16ms/step - loss: 5.2695 - mae: 1.5210
# Epoch 243/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2901 - mae: 1.5260
# Epoch 244/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1409 - mae: 1.3822
# Epoch 245/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.3684 - mae: 1.6329
# Epoch 246/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1987 - mae: 1.4810
# Epoch 247/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.1529 - mae: 1.4217
# Epoch 248/500
# 7/7 [==============================] - 0s 16ms/step - loss: 5.0619 - mae: 1.3463
# Epoch 249/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.2681 - mae: 1.5643
# Epoch 250/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.2338 - mae: 1.5367
# Epoch 251/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.3936 - mae: 1.7096
# Epoch 252/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.3986 - mae: 1.7237
# Epoch 253/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.3636 - mae: 1.7099
# Epoch 254/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1865 - mae: 1.5187
# Epoch 255/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.2435 - mae: 1.5758
# Epoch 256/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.1700 - mae: 1.5191
# Epoch 257/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0047 - mae: 1.3242
# Epoch 258/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0664 - mae: 1.4193
# Epoch 259/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1590 - mae: 1.5421
# Epoch 260/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0759 - mae: 1.4374
# Epoch 261/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1765 - mae: 1.5390
# Epoch 262/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.1312 - mae: 1.5174
# Epoch 263/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0363 - mae: 1.4184
# Epoch 264/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0609 - mae: 1.4567
# Epoch 265/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1043 - mae: 1.5142
# Epoch 266/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1171 - mae: 1.5320
# Epoch 267/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0426 - mae: 1.4601
# Epoch 268/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0033 - mae: 1.4240
# Epoch 269/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.9990 - mae: 1.4357
# Epoch 270/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0452 - mae: 1.4990
# Epoch 271/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1613 - mae: 1.5950
# Epoch 272/500
# 7/7 [==============================] - 0s 17ms/step - loss: 5.0944 - mae: 1.5711
# Epoch 273/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.2493 - mae: 1.7299
# Epoch 274/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1107 - mae: 1.5805
# Epoch 275/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.8792 - mae: 1.3225
# Epoch 276/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0186 - mae: 1.4989
# Epoch 277/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.9791 - mae: 1.4622
# Epoch 278/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.9830 - mae: 1.4914
# Epoch 279/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9412 - mae: 1.4479
# Epoch 280/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1243 - mae: 1.6380
# Epoch 281/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2528 - mae: 1.7737
# Epoch 282/500
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0365 - mae: 1.5726
# Epoch 283/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0221 - mae: 1.5562
# Epoch 284/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9827 - mae: 1.5128
# Epoch 285/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.9570 - mae: 1.5157
# Epoch 286/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0998 - mae: 1.6491
# Epoch 287/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.8702 - mae: 1.4433
# Epoch 288/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.8538 - mae: 1.4041
# Epoch 289/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9632 - mae: 1.5374
# Epoch 290/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.9587 - mae: 1.5566
# Epoch 291/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9615 - mae: 1.5490
# Epoch 292/500
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0522 - mae: 1.6448
# Epoch 293/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9941 - mae: 1.5972
# Epoch 294/500
# 7/7 [==============================] - 0s 19ms/step - loss: 4.8638 - mae: 1.4742
# Epoch 295/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.9267 - mae: 1.5349
# Epoch 296/500
# 7/7 [==============================] - 0s 21ms/step - loss: 5.0928 - mae: 1.7083
# Epoch 297/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.9327 - mae: 1.5600
# Epoch 298/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.8702 - mae: 1.4998
# Epoch 299/500
# 7/7 [==============================] - 0s 24ms/step - loss: 4.8454 - mae: 1.4705
# Epoch 300/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.7674 - mae: 1.4008
# Epoch 301/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.7918 - mae: 1.4295
# Epoch 302/500
# 7/7 [==============================] - 0s 20ms/step - loss: 4.7034 - mae: 1.3584
# Epoch 303/500
# 7/7 [==============================] - 0s 20ms/step - loss: 4.9029 - mae: 1.5576
# Epoch 304/500
# 7/7 [==============================] - 0s 19ms/step - loss: 4.7539 - mae: 1.4088
# Epoch 305/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.7347 - mae: 1.3883
# Epoch 306/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.7746 - mae: 1.4536
# Epoch 307/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.7471 - mae: 1.4098
# Epoch 308/500
# 7/7 [==============================] - 0s 18ms/step - loss: 4.6784 - mae: 1.3660
# Epoch 309/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.7383 - mae: 1.4114
# Epoch 310/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.8191 - mae: 1.5102
# Epoch 311/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.8612 - mae: 1.5743
# Epoch 312/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.7416 - mae: 1.4453
# Epoch 313/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6951 - mae: 1.4134
# Epoch 314/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.6519 - mae: 1.3707
# Epoch 315/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.8225 - mae: 1.5617
# Epoch 316/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.6115 - mae: 1.3122
# Epoch 317/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.7372 - mae: 1.4735
# Epoch 318/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.7156 - mae: 1.4632
# Epoch 319/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6431 - mae: 1.3737
# Epoch 320/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6890 - mae: 1.4314
# Epoch 321/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6298 - mae: 1.3896
# Epoch 322/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.6539 - mae: 1.4350
# Epoch 323/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.7043 - mae: 1.4762
# Epoch 324/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.7217 - mae: 1.4921
# Epoch 325/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5808 - mae: 1.3436
# Epoch 326/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.7202 - mae: 1.5097
# Epoch 327/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5283 - mae: 1.3014
# Epoch 328/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5324 - mae: 1.3238
# Epoch 329/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.6638 - mae: 1.4736
# Epoch 330/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.6199 - mae: 1.4255
# Epoch 331/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5159 - mae: 1.2964
# Epoch 332/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5789 - mae: 1.4005
# Epoch 333/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5192 - mae: 1.3413
# Epoch 334/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.5786 - mae: 1.3822
# Epoch 335/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.6778 - mae: 1.5097
# Epoch 336/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.4895 - mae: 1.3198
# Epoch 337/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4850 - mae: 1.3180
# Epoch 338/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.4994 - mae: 1.3409
# Epoch 339/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4786 - mae: 1.3193
# Epoch 340/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6020 - mae: 1.4664
# Epoch 341/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5221 - mae: 1.3741
# Epoch 342/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5255 - mae: 1.3930
# Epoch 343/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.6116 - mae: 1.4755
# Epoch 344/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5214 - mae: 1.4054
# Epoch 345/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5864 - mae: 1.4752
# Epoch 346/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.5053 - mae: 1.3823
# Epoch 347/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4132 - mae: 1.3127
# Epoch 348/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5061 - mae: 1.4080
# Epoch 349/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.5495 - mae: 1.4672
# Epoch 350/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6167 - mae: 1.5295
# Epoch 351/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.8133 - mae: 1.7533
# Epoch 352/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5258 - mae: 1.4630
# Epoch 353/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.4514 - mae: 1.3796
# Epoch 354/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4475 - mae: 1.3930
# Epoch 355/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4005 - mae: 1.3348
# Epoch 356/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5075 - mae: 1.4437
# Epoch 357/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6008 - mae: 1.5763
# Epoch 358/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3688 - mae: 1.3227
# Epoch 359/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.4133 - mae: 1.3670
# Epoch 360/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6563 - mae: 1.6338
# Epoch 361/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6481 - mae: 1.6235
# Epoch 362/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5104 - mae: 1.4686
# Epoch 363/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.5228 - mae: 1.4923
# Epoch 364/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5307 - mae: 1.5293
# Epoch 365/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.4968 - mae: 1.4830
# Epoch 366/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.4565 - mae: 1.4582
# Epoch 367/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.4525 - mae: 1.4575
# Epoch 368/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.3623 - mae: 1.3687
# Epoch 369/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.3541 - mae: 1.3692
# Epoch 370/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5017 - mae: 1.5063
# Epoch 371/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.5265 - mae: 1.5549
# Epoch 372/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4605 - mae: 1.4940
# Epoch 373/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4375 - mae: 1.4708
# Epoch 374/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3046 - mae: 1.3319
# Epoch 375/500
# 7/7 [==============================] - 0s 13ms/step - loss: 4.4668 - mae: 1.5034
# Epoch 376/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.4438 - mae: 1.4898
# Epoch 377/500
# 7/7 [==============================] - 0s 25ms/step - loss: 4.3304 - mae: 1.3735
# Epoch 378/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.3566 - mae: 1.4064
# Epoch 379/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.3211 - mae: 1.3664
# Epoch 380/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.4250 - mae: 1.4821
# Epoch 381/500
# 7/7 [==============================] - 0s 20ms/step - loss: 4.4866 - mae: 1.5745
# Epoch 382/500
# 7/7 [==============================] - 0s 20ms/step - loss: 4.3994 - mae: 1.4581
# Epoch 383/500
# 7/7 [==============================] - 0s 23ms/step - loss: 4.2847 - mae: 1.3620
# Epoch 384/500
# 7/7 [==============================] - 0s 23ms/step - loss: 4.2350 - mae: 1.2997
# Epoch 385/500
# 7/7 [==============================] - 0s 19ms/step - loss: 4.3575 - mae: 1.4260
# Epoch 386/500
# 7/7 [==============================] - 0s 20ms/step - loss: 4.2674 - mae: 1.3596
# Epoch 387/500
# 7/7 [==============================] - 0s 19ms/step - loss: 4.2546 - mae: 1.3246
# Epoch 388/500
# 7/7 [==============================] - 0s 21ms/step - loss: 4.3589 - mae: 1.4549
# Epoch 389/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.2379 - mae: 1.3382
# Epoch 390/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2534 - mae: 1.3623
# Epoch 391/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.3778 - mae: 1.4890
# Epoch 392/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.4858 - mae: 1.6209
# Epoch 393/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.3408 - mae: 1.4804
# Epoch 394/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3512 - mae: 1.4668
# Epoch 395/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3096 - mae: 1.4355
# Epoch 396/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.4344 - mae: 1.5925
# Epoch 397/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.3867 - mae: 1.5223
# Epoch 398/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.4394 - mae: 1.5907
# Epoch 399/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.3706 - mae: 1.5009
# Epoch 400/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2134 - mae: 1.3529
# Epoch 401/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.3164 - mae: 1.4733
# Epoch 402/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2226 - mae: 1.3735
# Epoch 403/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.1830 - mae: 1.3463
# Epoch 404/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.3062 - mae: 1.4833
# Epoch 405/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.1658 - mae: 1.3290
# Epoch 406/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.2366 - mae: 1.4005
# Epoch 407/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3105 - mae: 1.5004
# Epoch 408/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2462 - mae: 1.4430
# Epoch 409/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.2464 - mae: 1.4383
# Epoch 410/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.3078 - mae: 1.5262
# Epoch 411/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3603 - mae: 1.5736
# Epoch 412/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.2556 - mae: 1.4674
# Epoch 413/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.2481 - mae: 1.4548
# Epoch 414/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.1670 - mae: 1.3853
# Epoch 415/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1864 - mae: 1.3956
# Epoch 416/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1562 - mae: 1.3822
# Epoch 417/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1226 - mae: 1.3496
# Epoch 418/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.2978 - mae: 1.5490
# Epoch 419/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.2394 - mae: 1.4905
# Epoch 420/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.1389 - mae: 1.3592
# Epoch 421/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.0736 - mae: 1.3129
# Epoch 422/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.1414 - mae: 1.3915
# Epoch 423/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1655 - mae: 1.4092
# Epoch 424/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.0046 - mae: 1.2542
# Epoch 425/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1208 - mae: 1.3723
# Epoch 426/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.0603 - mae: 1.2985
# Epoch 427/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.0535 - mae: 1.3103
# Epoch 428/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.1281 - mae: 1.3923
# Epoch 429/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.0636 - mae: 1.3449
# Epoch 430/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1939 - mae: 1.4644
# Epoch 431/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1048 - mae: 1.4081
# Epoch 432/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.2591 - mae: 1.5678
# Epoch 433/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.0997 - mae: 1.4028
# Epoch 434/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.0744 - mae: 1.3807
# Epoch 435/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1710 - mae: 1.4557
# Epoch 436/500
# 7/7 [==============================] - 0s 16ms/step - loss: 4.1313 - mae: 1.4448
# Epoch 437/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.0337 - mae: 1.3546
# Epoch 438/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9851 - mae: 1.2859
# Epoch 439/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.1619 - mae: 1.4877
# Epoch 440/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1512 - mae: 1.4815
# Epoch 441/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.1933 - mae: 1.5357
# Epoch 442/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1114 - mae: 1.4467
# Epoch 443/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1352 - mae: 1.4709
# Epoch 444/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.0375 - mae: 1.3711
# Epoch 445/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.9694 - mae: 1.3085
# Epoch 446/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.1458 - mae: 1.4874
# Epoch 447/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2354 - mae: 1.6004
# Epoch 448/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.2121 - mae: 1.5694
# Epoch 449/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2096 - mae: 1.5784
# Epoch 450/500
# 7/7 [==============================] - 0s 17ms/step - loss: 3.9952 - mae: 1.3442
# Epoch 451/500
# 7/7 [==============================] - 0s 25ms/step - loss: 3.9334 - mae: 1.3014
# Epoch 452/500
# 7/7 [==============================] - 0s 20ms/step - loss: 3.9887 - mae: 1.3525
# Epoch 453/500
# 7/7 [==============================] - 0s 22ms/step - loss: 3.9916 - mae: 1.3834
# Epoch 454/500
# 7/7 [==============================] - 0s 21ms/step - loss: 3.9842 - mae: 1.3670
# Epoch 455/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.0331 - mae: 1.4209
# Epoch 456/500
# 7/7 [==============================] - 0s 20ms/step - loss: 3.9901 - mae: 1.3639
# Epoch 457/500
# 7/7 [==============================] - 0s 19ms/step - loss: 3.9470 - mae: 1.3349
# Epoch 458/500
# 7/7 [==============================] - 0s 19ms/step - loss: 4.0160 - mae: 1.4032
# Epoch 459/500
# 7/7 [==============================] - 0s 23ms/step - loss: 3.9456 - mae: 1.3445
# Epoch 460/500
# 7/7 [==============================] - 0s 22ms/step - loss: 4.0682 - mae: 1.4656
# Epoch 461/500
# 7/7 [==============================] - 0s 24ms/step - loss: 3.9118 - mae: 1.2971
# Epoch 462/500
# 7/7 [==============================] - 0s 24ms/step - loss: 3.8960 - mae: 1.3200
# Epoch 463/500
# 7/7 [==============================] - 0s 24ms/step - loss: 3.9558 - mae: 1.3537
# Epoch 464/500
# 7/7 [==============================] - 0s 29ms/step - loss: 3.9965 - mae: 1.4116
# Epoch 465/500
# 7/7 [==============================] - 0s 26ms/step - loss: 3.8906 - mae: 1.3040
# Epoch 466/500
# 7/7 [==============================] - 0s 20ms/step - loss: 4.0116 - mae: 1.4418
# Epoch 467/500
# 7/7 [==============================] - 0s 21ms/step - loss: 3.8246 - mae: 1.2443
# Epoch 468/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9809 - mae: 1.4205
# Epoch 469/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9339 - mae: 1.3635
# Epoch 470/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.9331 - mae: 1.3656
# Epoch 471/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.9751 - mae: 1.4159
# Epoch 472/500
# 7/7 [==============================] - 0s 18ms/step - loss: 3.8727 - mae: 1.3125
# Epoch 473/500
# 7/7 [==============================] - 0s 14ms/step - loss: 4.0313 - mae: 1.4536
# Epoch 474/500
# 7/7 [==============================] - 0s 18ms/step - loss: 4.0106 - mae: 1.4638
# Epoch 475/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8851 - mae: 1.3244
# Epoch 476/500
# 7/7 [==============================] - 0s 15ms/step - loss: 4.0116 - mae: 1.4947
# Epoch 477/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.8576 - mae: 1.3191
# Epoch 478/500
# 7/7 [==============================] - 0s 17ms/step - loss: 3.8336 - mae: 1.2702
# Epoch 479/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9510 - mae: 1.4207
# Epoch 480/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.8656 - mae: 1.3271
# Epoch 481/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.8913 - mae: 1.3551
# Epoch 482/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.7686 - mae: 1.2274
# Epoch 483/500
# 7/7 [==============================] - 0s 14ms/step - loss: 3.9006 - mae: 1.3765
# Epoch 484/500
# 7/7 [==============================] - 0s 17ms/step - loss: 4.1394 - mae: 1.6377
# Epoch 485/500
# 7/7 [==============================] - 0s 14ms/step - loss: 3.9056 - mae: 1.3887
# Epoch 486/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9309 - mae: 1.4372
# Epoch 487/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8866 - mae: 1.3898
# Epoch 488/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8651 - mae: 1.3601
# Epoch 489/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8367 - mae: 1.3416
# Epoch 490/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8540 - mae: 1.3631
# Epoch 491/500
# 7/7 [==============================] - 0s 17ms/step - loss: 3.8519 - mae: 1.3562
# Epoch 492/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8878 - mae: 1.3831
# Epoch 493/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9143 - mae: 1.4397
# Epoch 494/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.7904 - mae: 1.3092
# Epoch 495/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.9047 - mae: 1.4360
# Epoch 496/500
# 7/7 [==============================] - 0s 13ms/step - loss: 3.7643 - mae: 1.2799
# Epoch 497/500
# 7/7 [==============================] - 0s 14ms/step - loss: 3.7285 - mae: 1.2554
# Epoch 498/500
# 7/7 [==============================] - 0s 16ms/step - loss: 3.9030 - mae: 1.4451
# Epoch 499/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8058 - mae: 1.3550
# Epoch 500/500
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8860 - mae: 1.4396

# %% [markdown]
# You can visualize the training and see if the loss and MAE are still trending down.

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='Epochs',
    ylabel='Accuracy',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# ## Model Prediction
#
# As before, you can get the predictions for the validation set time range and compute the metrics.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(date[split_time:], (x_valid, results), '-', 0, None, 'Weekly Forecasting', 'Time', 'Sales In Thousands', legend = ("Actual", "Predicted"))
# Out:
# 4/4 [==============================] - 1s 21ms/step

# %%
results = np.abs(results)

# %%
plot_series(time_valid, (x_valid, results), '-', 0, None, 'CNNBiLSTM Regularized Forecasting', 'Weeks', 'Sales in Thousands', legend = ("Actual", "Predicted"))

# %%
# Assuming y_true contains the true target values and y_pred contains the predicted values
def r2_score(y_true, y_pred):
    SS_res = np.sum((y_true - y_pred)**2)
    SS_tot = np.sum((y_true - np.mean(y_true))**2)
    r2 = 1 - (SS_res / SS_tot)
    return r2

# %%
# Compute the MAE
print("MAE: ", tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())

# Compute the mean squared error
mean_squared_error = tf.keras.metrics.mean_squared_error(x_valid, results).numpy()

# Compute the RMSE by taking the square root of the mean squared error
rmse = np.sqrt(mean_squared_error)

print("RMSE:", rmse)

r2 = r2_score(x_valid, results)
print("R2 score:", r2)
# Out:
# MAE:  1.5258267
# RMSE: 1.9455931
# R2 score: 0.26952959705319324

# %% [markdown]
# ## Wrap Up
#
# This concludes the final practice lab for this course! You implemented a deep and complex architecture composed of CNNs, RNNs, and DNNs. You'll be using the skills you developed throughout this course to complete the final assignment. Keep it up!

# %% [markdown]
# ## Optional
#
# In this optional section, you will look at another way to dynamically set the learning rate. As you may have noticed, training for a long time generates less and less changes to the loss and metrics. You can run the cell below to observe that again.

# %%
# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=3e-7, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=10)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 9s 19ms/step - loss: 3.8190 - mae: 1.3472
# Epoch 2/10
# 7/7 [==============================] - 0s 14ms/step - loss: 3.7918 - mae: 1.3346
# Epoch 3/10
# 7/7 [==============================] - 0s 14ms/step - loss: 3.6842 - mae: 1.1863
# Epoch 4/10
# 7/7 [==============================] - 0s 15ms/step - loss: 3.7411 - mae: 1.2843
# Epoch 5/10
# 7/7 [==============================] - 0s 15ms/step - loss: 3.7761 - mae: 1.3044
# Epoch 6/10
# 7/7 [==============================] - 0s 13ms/step - loss: 3.7927 - mae: 1.3208
# Epoch 7/10
# 7/7 [==============================] - 0s 13ms/step - loss: 3.7396 - mae: 1.2736
# Epoch 8/10
# 7/7 [==============================] - 0s 13ms/step - loss: 3.7852 - mae: 1.3249
# Epoch 9/10
# 7/7 [==============================] - 0s 13ms/step - loss: 3.8042 - mae: 1.3532
# Epoch 10/10
# 7/7 [==============================] - 0s 15ms/step - loss: 3.7331 - mae: 1.2456

# %% [markdown]
# At some point, the static learning rate you set might no longer be the optimal one when the model has been learning for some time. You may want to decrease it some more to see better improvements. One way to do that is to have your training loop gradually decay the learning rate per epoch. You can pass in a lambda function similar like the one you did for the learning rate scheduler earlier, or use [ExponentialDecay()](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay). This is a built in scheduler from the Keras API. This decays the learning rate defined by this function:
#
# ```
# def decayed_learning_rate(step):
#   return initial_learning_rate * decay_rate ^ (step / decay_steps)
# ```
#
# See how it is used below.

# %%
# Set the initial learning rate
initial_learning_rate=3e-7

# Define the scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=400,
    decay_rate=0.96,
    staircase=True)

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=50)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 6s 20ms/step - loss: 0.3931 - mae: 0.6552
# Epoch 2/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3622 - mae: 0.5839
# Epoch 3/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3781 - mae: 0.6164
# Epoch 4/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4162 - mae: 0.6650
# Epoch 5/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4283 - mae: 0.6662
# Epoch 6/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4247 - mae: 0.6497
# Epoch 7/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.4342 - mae: 0.6974
# Epoch 8/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3726 - mae: 0.5815
# Epoch 9/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4323 - mae: 0.6804
# Epoch 10/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4125 - mae: 0.6451
# Epoch 11/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3961 - mae: 0.6271
# Epoch 12/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3989 - mae: 0.6235
# Epoch 13/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4457 - mae: 0.6967
# Epoch 14/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4249 - mae: 0.6521
# Epoch 15/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4090 - mae: 0.6510
# Epoch 16/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4107 - mae: 0.6596
# Epoch 17/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4427 - mae: 0.6747
# Epoch 18/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4686 - mae: 0.7102
# Epoch 19/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3716 - mae: 0.5885
# Epoch 20/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4282 - mae: 0.6707
# Epoch 21/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4608 - mae: 0.7065
# Epoch 22/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.4114 - mae: 0.6552
# Epoch 23/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4079 - mae: 0.6690
# Epoch 24/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4051 - mae: 0.6431
# Epoch 25/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3891 - mae: 0.6259
# Epoch 26/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3928 - mae: 0.6254
# Epoch 27/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3904 - mae: 0.6397
# Epoch 28/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4313 - mae: 0.6683
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3904 - mae: 0.6228
# Epoch 30/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.4523 - mae: 0.6892
# Epoch 31/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4035 - mae: 0.6461
# Epoch 32/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4212 - mae: 0.6570
# Epoch 33/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4010 - mae: 0.6370
# Epoch 34/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4320 - mae: 0.6955
# Epoch 35/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4278 - mae: 0.6560
# Epoch 36/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4162 - mae: 0.6465
# Epoch 37/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4426 - mae: 0.6956
# Epoch 38/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3643 - mae: 0.5897
# Epoch 39/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4220 - mae: 0.6728
# Epoch 40/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4478 - mae: 0.6996
# Epoch 41/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4010 - mae: 0.6296
# Epoch 42/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4266 - mae: 0.6805
# Epoch 43/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3925 - mae: 0.6144
# Epoch 44/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3790 - mae: 0.6049
# Epoch 45/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3856 - mae: 0.6196
# Epoch 46/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4056 - mae: 0.6442
# Epoch 47/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3671 - mae: 0.5921
# Epoch 48/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4180 - mae: 0.6454
# Epoch 49/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3968 - mae: 0.6425
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4251 - mae: 0.6761

# %% [markdown]
# Now see the results by geting predicitons and computing the metrics.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 4/4 [==============================] - 3s 18ms/step

# %%
# Compute the MAE
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 2.1451762

# %%
# Compute the mean squared error
mean_squared_error = tf.keras.metrics.mean_squared_error(x_valid, results).numpy()

# Compute the RMSE by taking the square root of the mean squared error
rmse = np.sqrt(mean_squared_error)

print("RMSE:", rmse)

r2 = r2_score(x_valid, results)
print("R2 score:", r2)
# Out:
# RMSE: 2.7788787
# R2 score: -0.4901765991803362
