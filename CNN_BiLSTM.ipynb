# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/main/C4/W4/ungraded_labs/C4_W4_Lab_3_Sunspots_CNN_RNN_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Predicting Sunspots with Neural Networks
#
# At this point in the course, you should be able to explore different network architectures for forecasting. In the previous weeks, you've used DNNs, RNNs, and CNNs to build these different models. In the final practice lab for this course, you'll try one more configuration and that is a combination of all these types of networks: the data windows will pass through a convolution, followed by stacked LSTMs, followed by stacked dense layers. See if this improves results or you can just opt for simpler models.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %% [markdown]
# ## Utilities

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    ax = plt.axes()
    ax.set_facecolor('None')
    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# ## Download and Preview the Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Thesis/Datasets
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Thesis/Datasets

# %%
df = pd.read_csv("weekly_sales_data.csv")
# Convert the 'Date' column to datetime type
#df['Date'] = pd.to_datetime(df['Unnamed: 0'])
#df.drop('Unnamed: 0', axis=1, inplace=True)
# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             sales
# Date
# 2014-01-12   2.71
# 2014-01-19   1.25
# 2014-01-26   1.66
# 2014-02-02   0.62
# 2014-02-09   0.01

# %%
'''# Download the Dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
'''
# Out:
# '# Download the Dataset\n!wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv\n'

# %%
# Initialize lists
'''
time_step = []
sales = []
# Open CSV file
with open('./Sunspots.csv') as csvfile:

  # Initialize reader
  reader = csv.reader(csvfile, delimiter=',')

  # Skip the first line
  next(reader)

  # Append row and sunspot number to lists
  for row in reader:
    time_step.append(int(row[0]))
    sunspots.append(float(row[2]))

# Convert lists to numpy arrays
time = np.array(time_step)
series = np.array(sales)
'''
# Parameters
time = np.arange(len(df.index), dtype="float32")
date = df.index
series = df['sales'].values
print(type(series))

# Plot the results
#plot_series(date, series)

# Preview the data
plot_series(time, series, xlabel='Weeks', ylabel='Sales in Thousands')
# Out:
# <class 'numpy.ndarray'>

# %%
print(max(series))
# Out:
# 12.3

# %% [markdown]
# ## Split the Dataset

# %%
'''# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]
'''
import math
# Define the split time
split_time = math.floor(len(series) * 3 / 4)

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

print(len(time_train))
print(len(time_valid))
# Out:
# 156
# 52

# %% [markdown]
# ## Prepare Features and Labels

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# As mentioned in the lectures, if your results don't good, you can try tweaking the parameters here and see if the model will learn better.

# %%
# Parameters
window_size = 52
batch_size = 16

shuffle_buffer_size = 1000

# Generate the dataset windows
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# You've seen these layers before and here is how it's looks like when combined.

# %%
# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=16, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[None, 1]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(52, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(52)),
#  tf.keras.layers.Dense(26, activation="relu"),
#  tf.keras.layers.Dense(13, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100)
])

 # Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 16)          64
#
#  bidirectional (Bidirectiona  (None, None, 104)        28704
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 104)              65312
#  nal)
#
#  dense (Dense)               (None, 1)                 105
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 94,185
# Trainable params: 94,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
from io import BytesIO
# Create a buffer to save the model summary image
buffer = BytesIO()

# Plot the model summary and save it to a file
tf.keras.utils.plot_model(model, to_file="model_summary.png", show_shapes=True, show_layer_names=True)

# Display the saved image
img = plt.imread("model_summary.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
'''
# Define the L2 regularization parameter
l2_regularization = 0.01

# Define the dropout rate for LSTM layers
dropout_rate = 0.1

# Build the Model with regularization
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=5,
                           strides=1,
                           activation="relu",
                           padding='causal',
                           input_shape=[window_size, 1]),
    tf.keras.layers.LSTM(64, return_sequences=True, dropout=dropout_rate),
    tf.keras.layers.LSTM(64, dropout=dropout_rate),
    tf.keras.layers.Dense(30, activation="relu", kernel_regularizer=tf.keras.regularizers.l1_l2(l2_regularization)),
    tf.keras.layers.Dense(10, activation="relu", kernel_regularizer=tf.keras.regularizers.l1_l2(l2_regularization)),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# Print the model summary
model.summary()
'''
# Out:
# '\n# Define the L2 regularization parameter\nl2_regularization = 0.01\n\n# Define the dropout rate for LSTM layers\ndropout_rate = 0.1\n\n# Build the Model with regularization\nmodel = tf.keras.models.Sequential([\n    tf.keras.layers.Conv1D(filters=64, kernel_size=5,\n                           strides=1,\n                           activation="relu",\n                           padding=\'causal\',\n                           input_shape=[window_size, 1]),\n    tf.keras.layers.LSTM(64, return_sequences=True, dropout=dropout_rate),\n    tf.keras.layers.LSTM(64, dropout=dropout_rate),\n    tf.keras.layers.Dense(30, activation="relu", kernel_regularizer=tf.keras.regularizers.l1_l2(l2_regularization)),\n    tf.keras.layers.Dense(10, activation="relu", kernel_regularizer=tf.keras.regularizers.l1_l2(l2_regularization)),\n    tf.keras.layers.Dense(1),\n    tf.keras.layers.Lambda(lambda x: x * 400)\n])\n\n# Print the model summary\nmodel.summary()\n'

# %% [markdown]
# ## Tune the Learning Rate
#
# As usual, you will want to pick an optimal learning rate.

# %%
# Get initial weights
init_weights = model.get_weights()

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.Adam()

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 7/7 [==============================] - 25s 264ms/step - loss: 13.5479 - lr: 1.0000e-08
# Epoch 2/100
# 7/7 [==============================] - 1s 91ms/step - loss: 13.5441 - lr: 1.1220e-08
# Epoch 3/100
# 7/7 [==============================] - 1s 121ms/step - loss: 13.5394 - lr: 1.2589e-08
# Epoch 4/100
# 7/7 [==============================] - 1s 87ms/step - loss: 13.5342 - lr: 1.4125e-08
# Epoch 5/100
# 7/7 [==============================] - 1s 88ms/step - loss: 13.5286 - lr: 1.5849e-08
# Epoch 6/100
# 7/7 [==============================] - 1s 86ms/step - loss: 13.5227 - lr: 1.7783e-08
# Epoch 7/100
# 7/7 [==============================] - 1s 88ms/step - loss: 13.5159 - lr: 1.9953e-08
# Epoch 8/100
# 7/7 [==============================] - 1s 85ms/step - loss: 13.5080 - lr: 2.2387e-08
# Epoch 9/100
# 7/7 [==============================] - 1s 88ms/step - loss: 13.4992 - lr: 2.5119e-08
# Epoch 10/100
# 7/7 [==============================] - 1s 85ms/step - loss: 13.4892 - lr: 2.8184e-08
# Epoch 11/100
# 7/7 [==============================] - 1s 161ms/step - loss: 13.4781 - lr: 3.1623e-08
# Epoch 12/100
# 7/7 [==============================] - 1s 158ms/step - loss: 13.4657 - lr: 3.5481e-08
# Epoch 13/100
# 7/7 [==============================] - 1s 141ms/step - loss: 13.4518 - lr: 3.9811e-08
# Epoch 14/100
# 7/7 [==============================] - 1s 88ms/step - loss: 13.4362 - lr: 4.4668e-08
# Epoch 15/100
# 7/7 [==============================] - 1s 86ms/step - loss: 13.4186 - lr: 5.0119e-08
# Epoch 16/100
# 7/7 [==============================] - 1s 88ms/step - loss: 13.3988 - lr: 5.6234e-08
# Epoch 17/100
# 7/7 [==============================] - 1s 87ms/step - loss: 13.3765 - lr: 6.3096e-08
# Epoch 18/100
# 7/7 [==============================] - 1s 83ms/step - loss: 13.3518 - lr: 7.0795e-08
# Epoch 19/100
# 7/7 [==============================] - 1s 89ms/step - loss: 13.3238 - lr: 7.9433e-08
# Epoch 20/100
# 7/7 [==============================] - 1s 86ms/step - loss: 13.2925 - lr: 8.9125e-08
# Epoch 21/100
# 7/7 [==============================] - 1s 88ms/step - loss: 13.2574 - lr: 1.0000e-07
# Epoch 22/100
# 7/7 [==============================] - 1s 87ms/step - loss: 13.2182 - lr: 1.1220e-07
# Epoch 23/100
# 7/7 [==============================] - 1s 84ms/step - loss: 13.1741 - lr: 1.2589e-07
# Epoch 24/100
# 7/7 [==============================] - 1s 158ms/step - loss: 13.1248 - lr: 1.4125e-07
# Epoch 25/100
# 7/7 [==============================] - 1s 158ms/step - loss: 13.0693 - lr: 1.5849e-07
# Epoch 26/100
# 7/7 [==============================] - 1s 152ms/step - loss: 13.0070 - lr: 1.7783e-07
# Epoch 27/100
# 7/7 [==============================] - 1s 87ms/step - loss: 12.9371 - lr: 1.9953e-07
# Epoch 28/100
# 7/7 [==============================] - 1s 86ms/step - loss: 12.8587 - lr: 2.2387e-07
# Epoch 29/100
# 7/7 [==============================] - 1s 96ms/step - loss: 12.7708 - lr: 2.5119e-07
# Epoch 30/100
# 7/7 [==============================] - 1s 84ms/step - loss: 12.6718 - lr: 2.8184e-07
# Epoch 31/100
# 7/7 [==============================] - 1s 89ms/step - loss: 12.5611 - lr: 3.1623e-07
# Epoch 32/100
# 7/7 [==============================] - 1s 88ms/step - loss: 12.4372 - lr: 3.5481e-07
# Epoch 33/100
# 7/7 [==============================] - 1s 91ms/step - loss: 12.2975 - lr: 3.9811e-07
# Epoch 34/100
# 7/7 [==============================] - 1s 134ms/step - loss: 12.1401 - lr: 4.4668e-07
# Epoch 35/100
# 7/7 [==============================] - 1s 167ms/step - loss: 11.9650 - lr: 5.0119e-07
# Epoch 36/100
# 7/7 [==============================] - 1s 173ms/step - loss: 11.7683 - lr: 5.6234e-07
# Epoch 37/100
# 7/7 [==============================] - 1s 165ms/step - loss: 11.5474 - lr: 6.3096e-07
# Epoch 38/100
# 7/7 [==============================] - 1s 166ms/step - loss: 11.2993 - lr: 7.0795e-07
# Epoch 39/100
# 7/7 [==============================] - 1s 160ms/step - loss: 11.0226 - lr: 7.9433e-07
# Epoch 40/100
# 7/7 [==============================] - 1s 161ms/step - loss: 10.7118 - lr: 8.9125e-07
# Epoch 41/100
# 7/7 [==============================] - 1s 91ms/step - loss: 10.3614 - lr: 1.0000e-06
# Epoch 42/100
# 7/7 [==============================] - 1s 95ms/step - loss: 9.9682 - lr: 1.1220e-06
# Epoch 43/100
# 7/7 [==============================] - 1s 89ms/step - loss: 9.5300 - lr: 1.2589e-06
# Epoch 44/100
# 7/7 [==============================] - 1s 96ms/step - loss: 9.0354 - lr: 1.4125e-06
# Epoch 45/100
# 7/7 [==============================] - 1s 92ms/step - loss: 8.4785 - lr: 1.5849e-06
# Epoch 46/100
# 7/7 [==============================] - 1s 94ms/step - loss: 7.8583 - lr: 1.7783e-06
# Epoch 47/100
# 7/7 [==============================] - 1s 91ms/step - loss: 7.1639 - lr: 1.9953e-06
# Epoch 48/100
# 7/7 [==============================] - 1s 88ms/step - loss: 6.3963 - lr: 2.2387e-06
# Epoch 49/100
# 7/7 [==============================] - 1s 85ms/step - loss: 5.5669 - lr: 2.5119e-06
# Epoch 50/100
# 7/7 [==============================] - 1s 92ms/step - loss: 4.7537 - lr: 2.8184e-06
# Epoch 51/100
# 7/7 [==============================] - 1s 88ms/step - loss: 3.9079 - lr: 3.1623e-06
# Epoch 52/100
# 7/7 [==============================] - 1s 165ms/step - loss: 3.2272 - lr: 3.5481e-06
# Epoch 53/100
# 7/7 [==============================] - 1s 167ms/step - loss: 2.7789 - lr: 3.9811e-06
# Epoch 54/100
# 7/7 [==============================] - 1s 167ms/step - loss: 2.4891 - lr: 4.4668e-06
# Epoch 55/100
# 7/7 [==============================] - 1s 130ms/step - loss: 2.3950 - lr: 5.0119e-06
# Epoch 56/100
# 7/7 [==============================] - 1s 90ms/step - loss: 2.3459 - lr: 5.6234e-06
# Epoch 57/100
# 7/7 [==============================] - 1s 94ms/step - loss: 2.3162 - lr: 6.3096e-06
# Epoch 58/100
# 7/7 [==============================] - 1s 90ms/step - loss: 2.2822 - lr: 7.0795e-06
# Epoch 59/100
# 7/7 [==============================] - 1s 90ms/step - loss: 2.2308 - lr: 7.9433e-06
# Epoch 60/100
# 7/7 [==============================] - 1s 89ms/step - loss: 2.1730 - lr: 8.9125e-06
# Epoch 61/100
# 7/7 [==============================] - 1s 85ms/step - loss: 2.1223 - lr: 1.0000e-05
# Epoch 62/100
# 7/7 [==============================] - 1s 90ms/step - loss: 2.0544 - lr: 1.1220e-05
# Epoch 63/100
# 7/7 [==============================] - 1s 88ms/step - loss: 1.9965 - lr: 1.2589e-05
# Epoch 64/100
# 7/7 [==============================] - 1s 89ms/step - loss: 1.9308 - lr: 1.4125e-05
# Epoch 65/100
# 7/7 [==============================] - 1s 161ms/step - loss: 1.8514 - lr: 1.5849e-05
# Epoch 66/100
# 7/7 [==============================] - 1s 170ms/step - loss: 1.7880 - lr: 1.7783e-05
# Epoch 67/100
# 7/7 [==============================] - 1s 166ms/step - loss: 1.7085 - lr: 1.9953e-05
# Epoch 68/100
# 7/7 [==============================] - 1s 117ms/step - loss: 1.6715 - lr: 2.2387e-05
# Epoch 69/100
# 7/7 [==============================] - 1s 90ms/step - loss: 1.5882 - lr: 2.5119e-05
# Epoch 70/100
# 7/7 [==============================] - 1s 88ms/step - loss: 1.5716 - lr: 2.8184e-05
# Epoch 71/100
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5075 - lr: 3.1623e-05
# Epoch 72/100
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4656 - lr: 3.5481e-05
# Epoch 73/100
# 7/7 [==============================] - 1s 100ms/step - loss: 1.4315 - lr: 3.9811e-05
# Epoch 74/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4010 - lr: 4.4668e-05
# Epoch 75/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.4080 - lr: 5.0119e-05
# Epoch 76/100
# 7/7 [==============================] - 1s 96ms/step - loss: 1.4575 - lr: 5.6234e-05
# Epoch 77/100
# 7/7 [==============================] - 1s 135ms/step - loss: 1.4073 - lr: 6.3096e-05
# Epoch 78/100
# 7/7 [==============================] - 1s 162ms/step - loss: 1.3618 - lr: 7.0795e-05
# Epoch 79/100
# 7/7 [==============================] - 1s 162ms/step - loss: 1.3356 - lr: 7.9433e-05
# Epoch 80/100
# 7/7 [==============================] - 1s 161ms/step - loss: 1.3932 - lr: 8.9125e-05
# Epoch 81/100
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3807 - lr: 1.0000e-04
# Epoch 82/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3732 - lr: 1.1220e-04
# Epoch 83/100
# 7/7 [==============================] - 1s 94ms/step - loss: 1.3893 - lr: 1.2589e-04
# Epoch 84/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3351 - lr: 1.4125e-04
# Epoch 85/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3946 - lr: 1.5849e-04
# Epoch 86/100
# 7/7 [==============================] - 1s 95ms/step - loss: 1.2230 - lr: 1.7783e-04
# Epoch 87/100
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2083 - lr: 1.9953e-04
# Epoch 88/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.1552 - lr: 2.2387e-04
# Epoch 89/100
# 7/7 [==============================] - 1s 89ms/step - loss: 1.1871 - lr: 2.5119e-04
# Epoch 90/100
# 7/7 [==============================] - 1s 85ms/step - loss: 1.4373 - lr: 2.8184e-04
# Epoch 91/100
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3944 - lr: 3.1623e-04
# Epoch 92/100
# 7/7 [==============================] - 1s 167ms/step - loss: 1.4004 - lr: 3.5481e-04
# Epoch 93/100
# 7/7 [==============================] - 2s 360ms/step - loss: 1.3713 - lr: 3.9811e-04
# Epoch 94/100
# 7/7 [==============================] - 1s 88ms/step - loss: 1.4323 - lr: 4.4668e-04
# Epoch 95/100
# 7/7 [==============================] - 1s 89ms/step - loss: 2.9252 - lr: 5.0119e-04
# Epoch 96/100
# 7/7 [==============================] - 1s 96ms/step - loss: 2.1943 - lr: 5.6234e-04
# Epoch 97/100
# 7/7 [==============================] - 1s 92ms/step - loss: 2.4741 - lr: 6.3096e-04
# Epoch 98/100
# 7/7 [==============================] - 1s 95ms/step - loss: 3.8883 - lr: 7.0795e-04
# Epoch 99/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.3103 - lr: 7.9433e-04
# Epoch 100/100
# 7/7 [==============================] - 1s 88ms/step - loss: 3.1183 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 50])
# Out:
# (1e-08, 0.001, 0.0, 50.0)

# %% [markdown]
# ## Train the Model
#
# Now you can proceed to reset and train the model. It is set for 100 epochs in the cell below but feel free to increase it if you want. Laurence got his results in the lectures after 500.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %%
# Set the learning rate
learning_rate = 1e-6

# Set the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Train the model
history = model.fit(train_set,epochs=500)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 11s 91ms/step - loss: 13.4009 - mae: 13.9009
# Epoch 2/500
# 7/7 [==============================] - 1s 83ms/step - loss: 13.0278 - mae: 13.5278
# Epoch 3/500
# 7/7 [==============================] - 1s 82ms/step - loss: 12.6536 - mae: 13.1536
# Epoch 4/500
# 7/7 [==============================] - 1s 86ms/step - loss: 12.2754 - mae: 12.7754
# Epoch 5/500
# 7/7 [==============================] - 1s 83ms/step - loss: 11.8985 - mae: 12.3985
# Epoch 6/500
# 7/7 [==============================] - 1s 98ms/step - loss: 11.5193 - mae: 12.0193
# Epoch 7/500
# 7/7 [==============================] - 1s 100ms/step - loss: 11.1445 - mae: 11.6445
# Epoch 8/500
# 7/7 [==============================] - 3s 411ms/step - loss: 10.7679 - mae: 11.2679
# Epoch 9/500
# 7/7 [==============================] - 2s 245ms/step - loss: 10.3904 - mae: 10.8904
# Epoch 10/500
# 7/7 [==============================] - 1s 97ms/step - loss: 10.0145 - mae: 10.5145
# Epoch 11/500
# 7/7 [==============================] - 1s 98ms/step - loss: 9.6403 - mae: 10.1403
# Epoch 12/500
# 7/7 [==============================] - 1s 93ms/step - loss: 9.2632 - mae: 9.7632
# Epoch 13/500
# 7/7 [==============================] - 1s 99ms/step - loss: 8.8892 - mae: 9.3892
# Epoch 14/500
# 7/7 [==============================] - 1s 102ms/step - loss: 8.5147 - mae: 9.0147
# Epoch 15/500
# 7/7 [==============================] - 1s 97ms/step - loss: 8.1387 - mae: 8.6383
# Epoch 16/500
# 7/7 [==============================] - 1s 96ms/step - loss: 7.7644 - mae: 8.2632
# Epoch 17/500
# 7/7 [==============================] - 1s 89ms/step - loss: 7.3935 - mae: 7.8901
# Epoch 18/500
# 7/7 [==============================] - 1s 83ms/step - loss: 7.0231 - mae: 7.5196
# Epoch 19/500
# 7/7 [==============================] - 1s 87ms/step - loss: 6.6573 - mae: 7.1559
# Epoch 20/500
# 7/7 [==============================] - 1s 151ms/step - loss: 6.2932 - mae: 6.7896
# Epoch 21/500
# 7/7 [==============================] - 1s 159ms/step - loss: 5.9405 - mae: 6.4313
# Epoch 22/500
# 7/7 [==============================] - 1s 165ms/step - loss: 5.5955 - mae: 6.0791
# Epoch 23/500
# 7/7 [==============================] - 1s 148ms/step - loss: 5.2669 - mae: 5.7554
# Epoch 24/500
# 7/7 [==============================] - 1s 89ms/step - loss: 4.9521 - mae: 5.4342
# Epoch 25/500
# 7/7 [==============================] - 1s 86ms/step - loss: 4.6462 - mae: 5.1274
# Epoch 26/500
# 7/7 [==============================] - 1s 94ms/step - loss: 4.3609 - mae: 4.8455
# Epoch 27/500
# 7/7 [==============================] - 1s 92ms/step - loss: 4.0984 - mae: 4.5864
# Epoch 28/500
# 7/7 [==============================] - 1s 88ms/step - loss: 3.8492 - mae: 4.3335
# Epoch 29/500
# 7/7 [==============================] - 1s 90ms/step - loss: 3.6248 - mae: 4.1007
# Epoch 30/500
# 7/7 [==============================] - 1s 91ms/step - loss: 3.4149 - mae: 3.8749
# Epoch 31/500
# 7/7 [==============================] - 1s 90ms/step - loss: 3.2450 - mae: 3.6989
# Epoch 32/500
# 7/7 [==============================] - 1s 85ms/step - loss: 3.0951 - mae: 3.5428
# Epoch 33/500
# 7/7 [==============================] - 1s 172ms/step - loss: 2.9602 - mae: 3.4114
# Epoch 34/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2.8555 - mae: 3.3162
# Epoch 35/500
# 7/7 [==============================] - 1s 157ms/step - loss: 2.7614 - mae: 3.2235
# Epoch 36/500
# 7/7 [==============================] - 1s 87ms/step - loss: 2.6894 - mae: 3.1529
# Epoch 37/500
# 7/7 [==============================] - 1s 104ms/step - loss: 2.6325 - mae: 3.0966
# Epoch 38/500
# 7/7 [==============================] - 1s 99ms/step - loss: 2.5674 - mae: 3.0265
# Epoch 39/500
# 7/7 [==============================] - 1s 101ms/step - loss: 2.5336 - mae: 2.9860
# Epoch 40/500
# 7/7 [==============================] - 1s 93ms/step - loss: 2.4979 - mae: 2.9477
# Epoch 41/500
# 7/7 [==============================] - 1s 94ms/step - loss: 2.4783 - mae: 2.9242
# Epoch 42/500
# 7/7 [==============================] - 1s 97ms/step - loss: 2.4489 - mae: 2.8941
# Epoch 43/500
# 7/7 [==============================] - 1s 100ms/step - loss: 2.4285 - mae: 2.8736
# Epoch 44/500
# 7/7 [==============================] - 1s 97ms/step - loss: 2.4115 - mae: 2.8586
# Epoch 45/500
# 7/7 [==============================] - 1s 98ms/step - loss: 2.3975 - mae: 2.8469
# Epoch 46/500
# 7/7 [==============================] - 1s 193ms/step - loss: 2.3814 - mae: 2.8316
# Epoch 47/500
# 7/7 [==============================] - 1s 197ms/step - loss: 2.3686 - mae: 2.8210
# Epoch 48/500
# 7/7 [==============================] - 1s 100ms/step - loss: 2.3591 - mae: 2.8133
# Epoch 49/500
# 7/7 [==============================] - 1s 97ms/step - loss: 2.3477 - mae: 2.8042
# Epoch 50/500
# 7/7 [==============================] - 1s 101ms/step - loss: 2.3379 - mae: 2.7955
# Epoch 51/500
# 7/7 [==============================] - 1s 87ms/step - loss: 2.3289 - mae: 2.7869
# Epoch 52/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.3203 - mae: 2.7792
# Epoch 53/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.3111 - mae: 2.7705
# Epoch 54/500
# 7/7 [==============================] - 1s 99ms/step - loss: 2.3034 - mae: 2.7631
# Epoch 55/500
# 7/7 [==============================] - 1s 92ms/step - loss: 2.2951 - mae: 2.7544
# Epoch 56/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.2867 - mae: 2.7460
# Epoch 57/500
# 7/7 [==============================] - 1s 87ms/step - loss: 2.2797 - mae: 2.7392
# Epoch 58/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.2716 - mae: 2.7311
# Epoch 59/500
# 7/7 [==============================] - 1s 113ms/step - loss: 2.2635 - mae: 2.7226
# Epoch 60/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2.2565 - mae: 2.7161
# Epoch 61/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2.2483 - mae: 2.7079
# Epoch 62/500
# 7/7 [==============================] - 1s 170ms/step - loss: 2.2409 - mae: 2.7006
# Epoch 63/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.2332 - mae: 2.6926
# Epoch 64/500
# 7/7 [==============================] - 1s 94ms/step - loss: 2.2259 - mae: 2.6847
# Epoch 65/500
# 7/7 [==============================] - 1s 101ms/step - loss: 2.2181 - mae: 2.6765
# Epoch 66/500
# 7/7 [==============================] - 1s 101ms/step - loss: 2.2108 - mae: 2.6689
# Epoch 67/500
# 7/7 [==============================] - 1s 96ms/step - loss: 2.2040 - mae: 2.6622
# Epoch 68/500
# 7/7 [==============================] - 1s 93ms/step - loss: 2.1958 - mae: 2.6537
# Epoch 69/500
# 7/7 [==============================] - 1s 101ms/step - loss: 2.1889 - mae: 2.6468
# Epoch 70/500
# 7/7 [==============================] - 1s 92ms/step - loss: 2.1810 - mae: 2.6391
# Epoch 71/500
# 7/7 [==============================] - 1s 142ms/step - loss: 2.1743 - mae: 2.6323
# Epoch 72/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2.1662 - mae: 2.6239
# Epoch 73/500
# 7/7 [==============================] - 1s 89ms/step - loss: 2.1589 - mae: 2.6159
# Epoch 74/500
# 7/7 [==============================] - 1s 92ms/step - loss: 2.1512 - mae: 2.6078
# Epoch 75/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.1455 - mae: 2.6028
# Epoch 76/500
# 7/7 [==============================] - 1s 90ms/step - loss: 2.1366 - mae: 2.5942
# Epoch 77/500
# 7/7 [==============================] - 1s 89ms/step - loss: 2.1288 - mae: 2.5865
# Epoch 78/500
# 7/7 [==============================] - 1s 97ms/step - loss: 2.1224 - mae: 2.5807
# Epoch 79/500
# 7/7 [==============================] - 1s 92ms/step - loss: 2.1145 - mae: 2.5733
# Epoch 80/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.1068 - mae: 2.5652
# Epoch 81/500
# 7/7 [==============================] - 1s 99ms/step - loss: 2.0991 - mae: 2.5576
# Epoch 82/500
# 7/7 [==============================] - 1s 89ms/step - loss: 2.0920 - mae: 2.5509
# Epoch 83/500
# 7/7 [==============================] - 1s 89ms/step - loss: 2.0849 - mae: 2.5447
# Epoch 84/500
# 7/7 [==============================] - 1s 164ms/step - loss: 2.0768 - mae: 2.5368
# Epoch 85/500
# 7/7 [==============================] - 1s 159ms/step - loss: 2.0686 - mae: 2.5283
# Epoch 86/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2.0623 - mae: 2.5213
# Epoch 87/500
# 7/7 [==============================] - 1s 136ms/step - loss: 2.0564 - mae: 2.5157
# Epoch 88/500
# 7/7 [==============================] - 1s 86ms/step - loss: 2.0476 - mae: 2.5069
# Epoch 89/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.0394 - mae: 2.4985
# Epoch 90/500
# 7/7 [==============================] - 1s 88ms/step - loss: 2.0342 - mae: 2.4920
# Epoch 91/500
# 7/7 [==============================] - 1s 91ms/step - loss: 2.0265 - mae: 2.4845
# Epoch 92/500
# 7/7 [==============================] - 1s 92ms/step - loss: 2.0184 - mae: 2.4769
# Epoch 93/500
# 7/7 [==============================] - 1s 93ms/step - loss: 2.0105 - mae: 2.4694
# Epoch 94/500
# 7/7 [==============================] - 1s 93ms/step - loss: 2.0040 - mae: 2.4631
# Epoch 95/500
# 7/7 [==============================] - 1s 96ms/step - loss: 1.9963 - mae: 2.4554
# Epoch 96/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.9894 - mae: 2.4489
# Epoch 97/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.9822 - mae: 2.4413
# Epoch 98/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.9751 - mae: 2.4340
# Epoch 99/500
# 7/7 [==============================] - 1s 167ms/step - loss: 1.9683 - mae: 2.4272
# Epoch 100/500
# 7/7 [==============================] - 1s 170ms/step - loss: 1.9610 - mae: 2.4200
# Epoch 101/500
# 7/7 [==============================] - 1s 168ms/step - loss: 1.9546 - mae: 2.4136
# Epoch 102/500
# 7/7 [==============================] - 1s 116ms/step - loss: 1.9479 - mae: 2.4067
# Epoch 103/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.9406 - mae: 2.3993
# Epoch 104/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.9335 - mae: 2.3920
# Epoch 105/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.9274 - mae: 2.3857
# Epoch 106/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.9213 - mae: 2.3792
# Epoch 107/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.9136 - mae: 2.3717
# Epoch 108/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.9064 - mae: 2.3644
# Epoch 109/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.9005 - mae: 2.3587
# Epoch 110/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.8933 - mae: 2.3513
# Epoch 111/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.8873 - mae: 2.3447
# Epoch 112/500
# 7/7 [==============================] - 1s 170ms/step - loss: 1.8811 - mae: 2.3375
# Epoch 113/500
# 7/7 [==============================] - 1s 167ms/step - loss: 1.8734 - mae: 2.3292
# Epoch 114/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.8682 - mae: 2.3236
# Epoch 115/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.8610 - mae: 2.3156
# Epoch 116/500
# 7/7 [==============================] - 1s 85ms/step - loss: 1.8556 - mae: 2.3101
# Epoch 117/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.8493 - mae: 2.3040
# Epoch 118/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.8430 - mae: 2.2974
# Epoch 119/500
# 7/7 [==============================] - 1s 97ms/step - loss: 1.8366 - mae: 2.2904
# Epoch 120/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.8307 - mae: 2.2849
# Epoch 121/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.8248 - mae: 2.2784
# Epoch 122/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.8205 - mae: 2.2735
# Epoch 123/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.8135 - mae: 2.2656
# Epoch 124/500
# 7/7 [==============================] - 1s 130ms/step - loss: 1.8070 - mae: 2.2582
# Epoch 125/500
# 7/7 [==============================] - 1s 163ms/step - loss: 1.8014 - mae: 2.2519
# Epoch 126/500
# 7/7 [==============================] - 1s 163ms/step - loss: 1.7973 - mae: 2.2463
# Epoch 127/500
# 7/7 [==============================] - 1s 131ms/step - loss: 1.7899 - mae: 2.2383
# Epoch 128/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.7846 - mae: 2.2325
# Epoch 129/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.7788 - mae: 2.2262
# Epoch 130/500
# 7/7 [==============================] - 1s 85ms/step - loss: 1.7727 - mae: 2.2189
# Epoch 131/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.7673 - mae: 2.2130
# Epoch 132/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.7619 - mae: 2.2064
# Epoch 133/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.7561 - mae: 2.1997
# Epoch 134/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.7513 - mae: 2.1945
# Epoch 135/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.7463 - mae: 2.1899
# Epoch 136/500
# 7/7 [==============================] - 1s 105ms/step - loss: 1.7409 - mae: 2.1839
# Epoch 137/500
# 7/7 [==============================] - 1s 158ms/step - loss: 1.7357 - mae: 2.1783
# Epoch 138/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.7303 - mae: 2.1726
# Epoch 139/500
# 7/7 [==============================] - 1s 124ms/step - loss: 1.7249 - mae: 2.1678
# Epoch 140/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.7196 - mae: 2.1616
# Epoch 141/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.7145 - mae: 2.1564
# Epoch 142/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.7102 - mae: 2.1529
# Epoch 143/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.7045 - mae: 2.1486
# Epoch 144/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.7005 - mae: 2.1452
# Epoch 145/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.6963 - mae: 2.1423
# Epoch 146/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.6900 - mae: 2.1362
# Epoch 147/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.6854 - mae: 2.1311
# Epoch 148/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.6818 - mae: 2.1268
# Epoch 149/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.6760 - mae: 2.1208
# Epoch 150/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.6731 - mae: 2.1179
# Epoch 151/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.6673 - mae: 2.1115
# Epoch 152/500
# 7/7 [==============================] - 1s 153ms/step - loss: 1.6634 - mae: 2.1074
# Epoch 153/500
# 7/7 [==============================] - 1s 169ms/step - loss: 1.6603 - mae: 2.1039
# Epoch 154/500
# 7/7 [==============================] - 1s 164ms/step - loss: 1.6553 - mae: 2.0989
# Epoch 155/500
# 7/7 [==============================] - 1s 148ms/step - loss: 1.6537 - mae: 2.0983
# Epoch 156/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.6475 - mae: 2.0917
# Epoch 157/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.6432 - mae: 2.0866
# Epoch 158/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.6385 - mae: 2.0817
# Epoch 159/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.6358 - mae: 2.0784
# Epoch 160/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.6312 - mae: 2.0737
# Epoch 161/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.6278 - mae: 2.0698
# Epoch 162/500
# 7/7 [==============================] - 1s 124ms/step - loss: 1.6242 - mae: 2.0654
# Epoch 163/500
# 7/7 [==============================] - 1s 165ms/step - loss: 1.6210 - mae: 2.0626
# Epoch 164/500
# 7/7 [==============================] - 1s 161ms/step - loss: 1.6167 - mae: 2.0586
# Epoch 165/500
# 7/7 [==============================] - 1s 174ms/step - loss: 1.6143 - mae: 2.0553
# Epoch 166/500
# 7/7 [==============================] - 1s 158ms/step - loss: 1.6094 - mae: 2.0499
# Epoch 167/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.6063 - mae: 2.0467
# Epoch 168/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.6025 - mae: 2.0429
# Epoch 169/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.6001 - mae: 2.0404
# Epoch 170/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.5960 - mae: 2.0360
# Epoch 171/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.5939 - mae: 2.0340
# Epoch 172/500
# 7/7 [==============================] - 1s 97ms/step - loss: 1.5902 - mae: 2.0299
# Epoch 173/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.5868 - mae: 2.0260
# Epoch 174/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5842 - mae: 2.0231
# Epoch 175/500
# 7/7 [==============================] - 1s 85ms/step - loss: 1.5815 - mae: 2.0200
# Epoch 176/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5772 - mae: 2.0158
# Epoch 177/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5753 - mae: 2.0134
# Epoch 178/500
# 7/7 [==============================] - 1s 167ms/step - loss: 1.5726 - mae: 2.0104
# Epoch 179/500
# 7/7 [==============================] - 1s 170ms/step - loss: 1.5691 - mae: 2.0064
# Epoch 180/500
# 7/7 [==============================] - 1s 150ms/step - loss: 1.5663 - mae: 2.0032
# Epoch 181/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.5632 - mae: 1.9998
# Epoch 182/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.5606 - mae: 1.9967
# Epoch 183/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.5580 - mae: 1.9938
# Epoch 184/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.5557 - mae: 1.9913
# Epoch 185/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.5525 - mae: 1.9877
# Epoch 186/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.5502 - mae: 1.9850
# Epoch 187/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5474 - mae: 1.9825
# Epoch 188/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5451 - mae: 1.9798
# Epoch 189/500
# 7/7 [==============================] - 1s 86ms/step - loss: 1.5420 - mae: 1.9761
# Epoch 190/500
# 7/7 [==============================] - 1s 97ms/step - loss: 1.5393 - mae: 1.9731
# Epoch 191/500
# 7/7 [==============================] - 1s 101ms/step - loss: 1.5365 - mae: 1.9698
# Epoch 192/500
# 7/7 [==============================] - 1s 167ms/step - loss: 1.5347 - mae: 1.9680
# Epoch 193/500
# 7/7 [==============================] - 1s 171ms/step - loss: 1.5341 - mae: 1.9679
# Epoch 194/500
# 7/7 [==============================] - 1s 168ms/step - loss: 1.5297 - mae: 1.9631
# Epoch 195/500
# 7/7 [==============================] - 1s 115ms/step - loss: 1.5277 - mae: 1.9598
# Epoch 196/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5247 - mae: 1.9558
# Epoch 197/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.5228 - mae: 1.9546
# Epoch 198/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.5206 - mae: 1.9524
# Epoch 199/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.5180 - mae: 1.9491
# Epoch 200/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.5161 - mae: 1.9472
# Epoch 201/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5147 - mae: 1.9459
# Epoch 202/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.5118 - mae: 1.9424
# Epoch 203/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.5086 - mae: 1.9390
# Epoch 204/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.5078 - mae: 1.9380
# Epoch 205/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.5040 - mae: 1.9354
# Epoch 206/500
# 7/7 [==============================] - 1s 171ms/step - loss: 1.5027 - mae: 1.9338
# Epoch 207/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.5008 - mae: 1.9309
# Epoch 208/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.4981 - mae: 1.9283
# Epoch 209/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4958 - mae: 1.9265
# Epoch 210/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4933 - mae: 1.9249
# Epoch 211/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4935 - mae: 1.9261
# Epoch 212/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4910 - mae: 1.9237
# Epoch 213/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.4890 - mae: 1.9208
# Epoch 214/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4867 - mae: 1.9183
# Epoch 215/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4852 - mae: 1.9165
# Epoch 216/500
# 7/7 [==============================] - 1s 96ms/step - loss: 1.4841 - mae: 1.9159
# Epoch 217/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4808 - mae: 1.9122
# Epoch 218/500
# 7/7 [==============================] - 1s 143ms/step - loss: 1.4793 - mae: 1.9094
# Epoch 219/500
# 7/7 [==============================] - 1s 172ms/step - loss: 1.4775 - mae: 1.9075
# Epoch 220/500
# 7/7 [==============================] - 1s 176ms/step - loss: 1.4752 - mae: 1.9051
# Epoch 221/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.4728 - mae: 1.9017
# Epoch 222/500
# 7/7 [==============================] - 1s 96ms/step - loss: 1.4709 - mae: 1.8988
# Epoch 223/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.4708 - mae: 1.8976
# Epoch 224/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4724 - mae: 1.8970
# Epoch 225/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4668 - mae: 1.8914
# Epoch 226/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.4678 - mae: 1.8931
# Epoch 227/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4624 - mae: 1.8904
# Epoch 228/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4608 - mae: 1.8886
# Epoch 229/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4593 - mae: 1.8875
# Epoch 230/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4595 - mae: 1.8886
# Epoch 231/500
# 7/7 [==============================] - 1s 173ms/step - loss: 1.4570 - mae: 1.8854
# Epoch 232/500
# 7/7 [==============================] - 1s 140ms/step - loss: 1.4540 - mae: 1.8808
# Epoch 233/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4525 - mae: 1.8790
# Epoch 234/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.4516 - mae: 1.8774
# Epoch 235/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4493 - mae: 1.8744
# Epoch 236/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.4482 - mae: 1.8733
# Epoch 237/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4468 - mae: 1.8718
# Epoch 238/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4454 - mae: 1.8711
# Epoch 239/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.4438 - mae: 1.8694
# Epoch 240/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.4428 - mae: 1.8681
# Epoch 241/500
# 7/7 [==============================] - 1s 161ms/step - loss: 1.4404 - mae: 1.8657
# Epoch 242/500
# 7/7 [==============================] - 1s 163ms/step - loss: 1.4393 - mae: 1.8647
# Epoch 243/500
# 7/7 [==============================] - 1s 149ms/step - loss: 1.4379 - mae: 1.8631
# Epoch 244/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.4365 - mae: 1.8610
# Epoch 245/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.4342 - mae: 1.8582
# Epoch 246/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.4332 - mae: 1.8573
# Epoch 247/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.4320 - mae: 1.8558
# Epoch 248/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.4302 - mae: 1.8547
# Epoch 249/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4283 - mae: 1.8526
# Epoch 250/500
# 7/7 [==============================] - 1s 97ms/step - loss: 1.4287 - mae: 1.8525
# Epoch 251/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4262 - mae: 1.8498
# Epoch 252/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.4244 - mae: 1.8480
# Epoch 253/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.4247 - mae: 1.8497
# Epoch 254/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.4224 - mae: 1.8465
# Epoch 255/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.4206 - mae: 1.8444
# Epoch 256/500
# 7/7 [==============================] - 1s 113ms/step - loss: 1.4200 - mae: 1.8431
# Epoch 257/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4193 - mae: 1.8424
# Epoch 258/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.4169 - mae: 1.8397
# Epoch 259/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.4159 - mae: 1.8389
# Epoch 260/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.4144 - mae: 1.8373
# Epoch 261/500
# 7/7 [==============================] - 1s 84ms/step - loss: 1.4142 - mae: 1.8366
# Epoch 262/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4125 - mae: 1.8353
# Epoch 263/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.4113 - mae: 1.8335
# Epoch 264/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4103 - mae: 1.8325
# Epoch 265/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4084 - mae: 1.8313
# Epoch 266/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4080 - mae: 1.8311
# Epoch 267/500
# 7/7 [==============================] - 1s 105ms/step - loss: 1.4063 - mae: 1.8290
# Epoch 268/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.4062 - mae: 1.8276
# Epoch 269/500
# 7/7 [==============================] - 1s 166ms/step - loss: 1.4042 - mae: 1.8261
# Epoch 270/500
# 7/7 [==============================] - 1s 133ms/step - loss: 1.4024 - mae: 1.8236
# Epoch 271/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.4012 - mae: 1.8224
# Epoch 272/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.4000 - mae: 1.8220
# Epoch 273/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.4006 - mae: 1.8242
# Epoch 274/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3991 - mae: 1.8242
# Epoch 275/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3983 - mae: 1.8220
# Epoch 276/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3957 - mae: 1.8166
# Epoch 277/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3952 - mae: 1.8167
# Epoch 278/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3950 - mae: 1.8158
# Epoch 279/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3935 - mae: 1.8140
# Epoch 280/500
# 7/7 [==============================] - 1s 163ms/step - loss: 1.3927 - mae: 1.8139
# Epoch 281/500
# 7/7 [==============================] - 1s 170ms/step - loss: 1.3906 - mae: 1.8116
# Epoch 282/500
# 7/7 [==============================] - 1s 170ms/step - loss: 1.3906 - mae: 1.8124
# Epoch 283/500
# 7/7 [==============================] - 1s 125ms/step - loss: 1.3882 - mae: 1.8105
# Epoch 284/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3873 - mae: 1.8107
# Epoch 285/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3861 - mae: 1.8093
# Epoch 286/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3848 - mae: 1.8078
# Epoch 287/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3838 - mae: 1.8071
# Epoch 288/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3861 - mae: 1.8076
# Epoch 289/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3816 - mae: 1.8023
# Epoch 290/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3804 - mae: 1.8016
# Epoch 291/500
# 7/7 [==============================] - 1s 98ms/step - loss: 1.3796 - mae: 1.8024
# Epoch 292/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3787 - mae: 1.8015
# Epoch 293/500
# 7/7 [==============================] - 1s 136ms/step - loss: 1.3789 - mae: 1.8029
# Epoch 294/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.3762 - mae: 1.7999
# Epoch 295/500
# 7/7 [==============================] - 1s 164ms/step - loss: 1.3760 - mae: 1.7983
# Epoch 296/500
# 7/7 [==============================] - 1s 117ms/step - loss: 1.3748 - mae: 1.7957
# Epoch 297/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3756 - mae: 1.7973
# Epoch 298/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3727 - mae: 1.7940
# Epoch 299/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3721 - mae: 1.7934
# Epoch 300/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3716 - mae: 1.7927
# Epoch 301/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3711 - mae: 1.7917
# Epoch 302/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3693 - mae: 1.7900
# Epoch 303/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.3676 - mae: 1.7894
# Epoch 304/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3667 - mae: 1.7885
# Epoch 305/500
# 7/7 [==============================] - 1s 128ms/step - loss: 1.3677 - mae: 1.7924
# Epoch 306/500
# 7/7 [==============================] - 1s 164ms/step - loss: 1.3653 - mae: 1.7899
# Epoch 307/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.3637 - mae: 1.7877
# Epoch 308/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.3628 - mae: 1.7855
# Epoch 309/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3646 - mae: 1.7860
# Epoch 310/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.3633 - mae: 1.7859
# Epoch 311/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3626 - mae: 1.7860
# Epoch 312/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3593 - mae: 1.7825
# Epoch 313/500
# 7/7 [==============================] - 1s 96ms/step - loss: 1.3582 - mae: 1.7806
# Epoch 314/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.3573 - mae: 1.7794
# Epoch 315/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3569 - mae: 1.7782
# Epoch 316/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.3562 - mae: 1.7775
# Epoch 317/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3561 - mae: 1.7771
# Epoch 318/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.3566 - mae: 1.7791
# Epoch 319/500
# 7/7 [==============================] - 1s 164ms/step - loss: 1.3539 - mae: 1.7786
# Epoch 320/500
# 7/7 [==============================] - 1s 166ms/step - loss: 1.3527 - mae: 1.7772
# Epoch 321/500
# 7/7 [==============================] - 1s 158ms/step - loss: 1.3518 - mae: 1.7756
# Epoch 322/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3504 - mae: 1.7739
# Epoch 323/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3494 - mae: 1.7724
# Epoch 324/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3487 - mae: 1.7714
# Epoch 325/500
# 7/7 [==============================] - 1s 86ms/step - loss: 1.3489 - mae: 1.7725
# Epoch 326/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3473 - mae: 1.7701
# Epoch 327/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3474 - mae: 1.7681
# Epoch 328/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3454 - mae: 1.7665
# Epoch 329/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3440 - mae: 1.7663
# Epoch 330/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3446 - mae: 1.7686
# Epoch 331/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3434 - mae: 1.7699
# Epoch 332/500
# 7/7 [==============================] - 1s 155ms/step - loss: 1.3420 - mae: 1.7681
# Epoch 333/500
# 7/7 [==============================] - 1s 154ms/step - loss: 1.3408 - mae: 1.7664
# Epoch 334/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.3399 - mae: 1.7647
# Epoch 335/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3407 - mae: 1.7628
# Epoch 336/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.3415 - mae: 1.7644
# Epoch 337/500
# 7/7 [==============================] - 1s 84ms/step - loss: 1.3383 - mae: 1.7602
# Epoch 338/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.3377 - mae: 1.7580
# Epoch 339/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.3379 - mae: 1.7598
# Epoch 340/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3351 - mae: 1.7578
# Epoch 341/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3340 - mae: 1.7571
# Epoch 342/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3336 - mae: 1.7572
# Epoch 343/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3337 - mae: 1.7569
# Epoch 344/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.3314 - mae: 1.7547
# Epoch 345/500
# 7/7 [==============================] - 1s 141ms/step - loss: 1.3305 - mae: 1.7522
# Epoch 346/500
# 7/7 [==============================] - 1s 161ms/step - loss: 1.3312 - mae: 1.7517
# Epoch 347/500
# 7/7 [==============================] - 1s 156ms/step - loss: 1.3299 - mae: 1.7508
# Epoch 348/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.3290 - mae: 1.7524
# Epoch 349/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3291 - mae: 1.7546
# Epoch 350/500
# 7/7 [==============================] - 1s 86ms/step - loss: 1.3282 - mae: 1.7530
# Epoch 351/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.3262 - mae: 1.7501
# Epoch 352/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.3256 - mae: 1.7486
# Epoch 353/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3251 - mae: 1.7480
# Epoch 354/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.3253 - mae: 1.7487
# Epoch 355/500
# 7/7 [==============================] - 1s 83ms/step - loss: 1.3226 - mae: 1.7450
# Epoch 356/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3233 - mae: 1.7435
# Epoch 357/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3235 - mae: 1.7417
# Epoch 358/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3218 - mae: 1.7410
# Epoch 359/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.3207 - mae: 1.7408
# Epoch 360/500
# 7/7 [==============================] - 1s 137ms/step - loss: 1.3200 - mae: 1.7415
# Epoch 361/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.3212 - mae: 1.7453
# Epoch 362/500
# 7/7 [==============================] - 1s 158ms/step - loss: 1.3190 - mae: 1.7435
# Epoch 363/500
# 7/7 [==============================] - 1s 133ms/step - loss: 1.3188 - mae: 1.7404
# Epoch 364/500
# 7/7 [==============================] - 1s 86ms/step - loss: 1.3187 - mae: 1.7395
# Epoch 365/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.3173 - mae: 1.7386
# Epoch 366/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.3156 - mae: 1.7378
# Epoch 367/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3150 - mae: 1.7364
# Epoch 368/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.3143 - mae: 1.7341
# Epoch 369/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3142 - mae: 1.7318
# Epoch 370/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3135 - mae: 1.7299
# Epoch 371/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3139 - mae: 1.7314
# Epoch 372/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3113 - mae: 1.7302
# Epoch 373/500
# 7/7 [==============================] - 1s 113ms/step - loss: 1.3106 - mae: 1.7292
# Epoch 374/500
# 7/7 [==============================] - 1s 161ms/step - loss: 1.3117 - mae: 1.7305
# Epoch 375/500
# 7/7 [==============================] - 1s 158ms/step - loss: 1.3095 - mae: 1.7281
# Epoch 376/500
# 7/7 [==============================] - 1s 156ms/step - loss: 1.3099 - mae: 1.7285
# Epoch 377/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3095 - mae: 1.7281
# Epoch 378/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3086 - mae: 1.7282
# Epoch 379/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3064 - mae: 1.7265
# Epoch 380/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.3067 - mae: 1.7275
# Epoch 381/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.3051 - mae: 1.7255
# Epoch 382/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.3047 - mae: 1.7239
# Epoch 383/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3041 - mae: 1.7223
# Epoch 384/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.3036 - mae: 1.7201
# Epoch 385/500
# 7/7 [==============================] - 1s 98ms/step - loss: 1.3030 - mae: 1.7226
# Epoch 386/500
# 7/7 [==============================] - 1s 163ms/step - loss: 1.3031 - mae: 1.7218
# Epoch 387/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.3020 - mae: 1.7215
# Epoch 388/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.3021 - mae: 1.7227
# Epoch 389/500
# 7/7 [==============================] - 1s 125ms/step - loss: 1.2998 - mae: 1.7197
# Epoch 390/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.3017 - mae: 1.7257
# Epoch 391/500
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2992 - mae: 1.7218
# Epoch 392/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2997 - mae: 1.7200
# Epoch 393/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2971 - mae: 1.7155
# Epoch 394/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2964 - mae: 1.7157
# Epoch 395/500
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2958 - mae: 1.7155
# Epoch 396/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2963 - mae: 1.7154
# Epoch 397/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2945 - mae: 1.7133
# Epoch 398/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2952 - mae: 1.7154
# Epoch 399/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2932 - mae: 1.7130
# Epoch 400/500
# 7/7 [==============================] - 1s 149ms/step - loss: 1.2957 - mae: 1.7107
# Epoch 401/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.2935 - mae: 1.7080
# Epoch 402/500
# 7/7 [==============================] - 1s 169ms/step - loss: 1.2931 - mae: 1.7112
# Epoch 403/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.2917 - mae: 1.7123
# Epoch 404/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2909 - mae: 1.7092
# Epoch 405/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2905 - mae: 1.7069
# Epoch 406/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2911 - mae: 1.7092
# Epoch 407/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.2891 - mae: 1.7082
# Epoch 408/500
# 7/7 [==============================] - 1s 99ms/step - loss: 1.2898 - mae: 1.7099
# Epoch 409/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2880 - mae: 1.7061
# Epoch 410/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2881 - mae: 1.7035
# Epoch 411/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2865 - mae: 1.7022
# Epoch 412/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2856 - mae: 1.7025
# Epoch 413/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2854 - mae: 1.7032
# Epoch 414/500
# 7/7 [==============================] - 1s 152ms/step - loss: 1.2848 - mae: 1.7011
# Epoch 415/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.2850 - mae: 1.7014
# Epoch 416/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2837 - mae: 1.7005
# Epoch 417/500
# 7/7 [==============================] - 1s 115ms/step - loss: 1.2836 - mae: 1.6991
# Epoch 418/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2827 - mae: 1.6974
# Epoch 419/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2831 - mae: 1.6978
# Epoch 420/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2813 - mae: 1.6965
# Epoch 421/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2829 - mae: 1.6951
# Epoch 422/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2819 - mae: 1.6951
# Epoch 423/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2801 - mae: 1.6956
# Epoch 424/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2818 - mae: 1.7002
# Epoch 425/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2787 - mae: 1.6954
# Epoch 426/500
# 7/7 [==============================] - 1s 125ms/step - loss: 1.2795 - mae: 1.6909
# Epoch 427/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.2783 - mae: 1.6892
# Epoch 428/500
# 7/7 [==============================] - 1s 159ms/step - loss: 1.2782 - mae: 1.6911
# Epoch 429/500
# 7/7 [==============================] - 1s 133ms/step - loss: 1.2786 - mae: 1.6936
# Epoch 430/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2761 - mae: 1.6915
# Epoch 431/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2761 - mae: 1.6924
# Epoch 432/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2753 - mae: 1.6928
# Epoch 433/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2746 - mae: 1.6924
# Epoch 434/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2754 - mae: 1.6924
# Epoch 435/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2758 - mae: 1.6929
# Epoch 436/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2739 - mae: 1.6898
# Epoch 437/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.2730 - mae: 1.6852
# Epoch 438/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2735 - mae: 1.6897
# Epoch 439/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2717 - mae: 1.6898
# Epoch 440/500
# 7/7 [==============================] - 1s 164ms/step - loss: 1.2715 - mae: 1.6901
# Epoch 441/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.2711 - mae: 1.6874
# Epoch 442/500
# 7/7 [==============================] - 1s 156ms/step - loss: 1.2697 - mae: 1.6843
# Epoch 443/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2707 - mae: 1.6841
# Epoch 444/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2696 - mae: 1.6834
# Epoch 445/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2680 - mae: 1.6826
# Epoch 446/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2686 - mae: 1.6825
# Epoch 447/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2672 - mae: 1.6802
# Epoch 448/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2666 - mae: 1.6798
# Epoch 449/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2665 - mae: 1.6796
# Epoch 450/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2658 - mae: 1.6777
# Epoch 451/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2656 - mae: 1.6757
# Epoch 452/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2652 - mae: 1.6759
# Epoch 453/500
# 7/7 [==============================] - 1s 116ms/step - loss: 1.2647 - mae: 1.6767
# Epoch 454/500
# 7/7 [==============================] - 1s 155ms/step - loss: 1.2643 - mae: 1.6761
# Epoch 455/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2638 - mae: 1.6750
# Epoch 456/500
# 7/7 [==============================] - 1s 149ms/step - loss: 1.2645 - mae: 1.6789
# Epoch 457/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2627 - mae: 1.6773
# Epoch 458/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2656 - mae: 1.6789
# Epoch 459/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2620 - mae: 1.6745
# Epoch 460/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2614 - mae: 1.6755
# Epoch 461/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2613 - mae: 1.6762
# Epoch 462/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2612 - mae: 1.6777
# Epoch 463/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.2613 - mae: 1.6767
# Epoch 464/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2592 - mae: 1.6711
# Epoch 465/500
# 7/7 [==============================] - 1s 96ms/step - loss: 1.2591 - mae: 1.6687
# Epoch 466/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2588 - mae: 1.6672
# Epoch 467/500
# 7/7 [==============================] - 1s 167ms/step - loss: 1.2587 - mae: 1.6664
# Epoch 468/500
# 7/7 [==============================] - 1s 152ms/step - loss: 1.2581 - mae: 1.6675
# Epoch 469/500
# 7/7 [==============================] - 1s 95ms/step - loss: 1.2568 - mae: 1.6678
# Epoch 470/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2565 - mae: 1.6674
# Epoch 471/500
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2570 - mae: 1.6684
# Epoch 472/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2555 - mae: 1.6660
# Epoch 473/500
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2558 - mae: 1.6642
# Epoch 474/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2549 - mae: 1.6633
# Epoch 475/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2600 - mae: 1.6730
# Epoch 476/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2546 - mae: 1.6680
# Epoch 477/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2533 - mae: 1.6638
# Epoch 478/500
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2529 - mae: 1.6633
# Epoch 479/500
# 7/7 [==============================] - 1s 154ms/step - loss: 1.2524 - mae: 1.6617
# Epoch 480/500
# 7/7 [==============================] - 1s 162ms/step - loss: 1.2532 - mae: 1.6612
# Epoch 481/500
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2516 - mae: 1.6595
# Epoch 482/500
# 7/7 [==============================] - 1s 129ms/step - loss: 1.2511 - mae: 1.6602
# Epoch 483/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2513 - mae: 1.6639
# Epoch 484/500
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2515 - mae: 1.6658
# Epoch 485/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2501 - mae: 1.6635
# Epoch 486/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2505 - mae: 1.6624
# Epoch 487/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2492 - mae: 1.6603
# Epoch 488/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2491 - mae: 1.6613
# Epoch 489/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2485 - mae: 1.6611
# Epoch 490/500
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2511 - mae: 1.6616
# Epoch 491/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2472 - mae: 1.6564
# Epoch 492/500
# 7/7 [==============================] - 1s 155ms/step - loss: 1.2488 - mae: 1.6604
# Epoch 493/500
# 7/7 [==============================] - 1s 157ms/step - loss: 1.2466 - mae: 1.6575
# Epoch 494/500
# 7/7 [==============================] - 1s 154ms/step - loss: 1.2466 - mae: 1.6570
# Epoch 495/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2461 - mae: 1.6540
# Epoch 496/500
# 7/7 [==============================] - 1s 94ms/step - loss: 1.2470 - mae: 1.6540
# Epoch 497/500
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2442 - mae: 1.6515
# Epoch 498/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2435 - mae: 1.6534
# Epoch 499/500
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2444 - mae: 1.6568
# Epoch 500/500
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2445 - mae: 1.6557

# %% [markdown]
# You can visualize the training and see if the loss and MAE are still trending down.

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='Epochs',
    ylabel='Accuracy',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# ## Model Prediction
#
# As before, you can get the predictions for the validation set time range and compute the metrics.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %%
'''
print(date[split_time:][1][0:7])
x_label = []
for i in range(0, 12):
  x_label.append(date[split_time:][i][0:7])

print(x_label)'''
# Out:
# '\nprint(date[split_time:][1][0:7])\nx_label = []\nfor i in range(0, 12):\n  x_label.append(date[split_time:][i][0:7])\n\nprint(x_label)'

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()
# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 4/4 [==============================] - 2s 40ms/step

# %%
results = np.abs(results)
plot_series(time_valid, (x_valid, results), '-', 0, None, 'Combined CNN, BiLSTM Forecasting', 'Weeks', 'Sales in Thousands', legend = ("Actual", "Predicted"))

# %%
# Assuming y_true contains the true target values and y_pred contains the predicted values
def r2_score(y_true, y_pred):
    SS_res = np.sum((y_true - y_pred)**2)
    SS_tot = np.sum((y_true - np.mean(y_true))**2)
    r2 = 1 - (SS_res / SS_tot)
    return r2

# %%
# Compute the MAE
print("MAE: ", tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())

# Compute the mean squared error
mean_squared_error = tf.keras.metrics.mean_squared_error(x_valid, results).numpy()

# Compute the RMSE by taking the square root of the mean squared error
rmse = np.sqrt(mean_squared_error)

print("RMSE:", rmse)

r2 = r2_score(x_valid, results)
print("R2 score:", r2)
# Out:
# MAE:  1.3884917
# RMSE: 1.5998023
# R2 score: 0.5061089368099212

# %% [markdown]
# ## Wrap Up
#
# This concludes the final practice lab for this course! You implemented a deep and complex architecture composed of CNNs, RNNs, and DNNs. You'll be using the skills you developed throughout this course to complete the final assignment. Keep it up!

# %% [markdown]
# ## Optional
#
# In this optional section, you will look at another way to dynamically set the learning rate. As you may have noticed, training for a long time generates less and less changes to the loss and metrics. You can run the cell below to observe that again.

# %%
# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=3e-7, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=10)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 9s 87ms/step - loss: 1.2440 - mae: 1.6563
# Epoch 2/10
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2470 - mae: 1.6582
# Epoch 3/10
# 7/7 [==============================] - 1s 83ms/step - loss: 1.2450 - mae: 1.6513
# Epoch 4/10
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2433 - mae: 1.6473
# Epoch 5/10
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2445 - mae: 1.6573
# Epoch 6/10
# 7/7 [==============================] - 1s 161ms/step - loss: 1.2557 - mae: 1.6741
# Epoch 7/10
# 7/7 [==============================] - 1s 166ms/step - loss: 1.2412 - mae: 1.6485
# Epoch 8/10
# 7/7 [==============================] - 1s 141ms/step - loss: 1.2451 - mae: 1.6487
# Epoch 9/10
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2439 - mae: 1.6532
# Epoch 10/10
# 7/7 [==============================] - 1s 95ms/step - loss: 1.2420 - mae: 1.6542

# %% [markdown]
# At some point, the static learning rate you set might no longer be the optimal one when the model has been learning for some time. You may want to decrease it some more to see better improvements. One way to do that is to have your training loop gradually decay the learning rate per epoch. You can pass in a lambda function similar like the one you did for the learning rate scheduler earlier, or use [ExponentialDecay()](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay). This is a built in scheduler from the Keras API. This decays the learning rate defined by this function:
#
# ```
# def decayed_learning_rate(step):
#   return initial_learning_rate * decay_rate ^ (step / decay_steps)
# ```
#
# See how it is used below.

# %%
# Set the initial learning rate
initial_learning_rate=3e-7

# Define the scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=400,
    decay_rate=0.96,
    staircase=True)

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=50)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 10s 170ms/step - loss: 1.2459 - mae: 1.6527
# Epoch 2/50
# 7/7 [==============================] - 1s 163ms/step - loss: 1.2416 - mae: 1.6467
# Epoch 3/50
# 7/7 [==============================] - 1s 154ms/step - loss: 1.2415 - mae: 1.6503
# Epoch 4/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2402 - mae: 1.6516
# Epoch 5/50
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2429 - mae: 1.6508
# Epoch 6/50
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2377 - mae: 1.6453
# Epoch 7/50
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2426 - mae: 1.6526
# Epoch 8/50
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2366 - mae: 1.6500
# Epoch 9/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2399 - mae: 1.6561
# Epoch 10/50
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2393 - mae: 1.6486
# Epoch 11/50
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2363 - mae: 1.6427
# Epoch 12/50
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2366 - mae: 1.6421
# Epoch 13/50
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2360 - mae: 1.6415
# Epoch 14/50
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2387 - mae: 1.6494
# Epoch 15/50
# 7/7 [==============================] - 1s 156ms/step - loss: 1.2370 - mae: 1.6507
# Epoch 16/50
# 7/7 [==============================] - 1s 162ms/step - loss: 1.2389 - mae: 1.6536
# Epoch 17/50
# 7/7 [==============================] - 1s 159ms/step - loss: 1.2374 - mae: 1.6463
# Epoch 18/50
# 7/7 [==============================] - 1s 104ms/step - loss: 1.2360 - mae: 1.6418
# Epoch 19/50
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2421 - mae: 1.6470
# Epoch 20/50
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2366 - mae: 1.6403
# Epoch 21/50
# 7/7 [==============================] - 1s 82ms/step - loss: 1.2410 - mae: 1.6451
# Epoch 22/50
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2315 - mae: 1.6434
# Epoch 23/50
# 7/7 [==============================] - 1s 84ms/step - loss: 1.2356 - mae: 1.6397
# Epoch 24/50
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2348 - mae: 1.6374
# Epoch 25/50
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2316 - mae: 1.6342
# Epoch 26/50
# 7/7 [==============================] - 1s 93ms/step - loss: 1.2359 - mae: 1.6485
# Epoch 27/50
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2347 - mae: 1.6435
# Epoch 28/50
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2374 - mae: 1.6407
# Epoch 29/50
# 7/7 [==============================] - 1s 82ms/step - loss: 1.2307 - mae: 1.6396
# Epoch 30/50
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2377 - mae: 1.6556
# Epoch 31/50
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2349 - mae: 1.6396
# Epoch 32/50
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2358 - mae: 1.6407
# Epoch 33/50
# 7/7 [==============================] - 1s 124ms/step - loss: 1.2288 - mae: 1.6362
# Epoch 34/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2294 - mae: 1.6379
# Epoch 35/50
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2304 - mae: 1.6353
# Epoch 36/50
# 7/7 [==============================] - 1s 85ms/step - loss: 1.2272 - mae: 1.6298
# Epoch 37/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2264 - mae: 1.6380
# Epoch 38/50
# 7/7 [==============================] - 1s 87ms/step - loss: 1.2371 - mae: 1.6554
# Epoch 39/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2274 - mae: 1.6357
# Epoch 40/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2297 - mae: 1.6325
# Epoch 41/50
# 7/7 [==============================] - 1s 126ms/step - loss: 1.2303 - mae: 1.6371
# Epoch 42/50
# 7/7 [==============================] - 1s 88ms/step - loss: 1.2298 - mae: 1.6384
# Epoch 43/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2248 - mae: 1.6307
# Epoch 44/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2301 - mae: 1.6334
# Epoch 45/50
# 7/7 [==============================] - 1s 166ms/step - loss: 1.2299 - mae: 1.6359
# Epoch 46/50
# 7/7 [==============================] - 1s 165ms/step - loss: 1.2243 - mae: 1.6320
# Epoch 47/50
# 7/7 [==============================] - 1s 160ms/step - loss: 1.2283 - mae: 1.6338
# Epoch 48/50
# 7/7 [==============================] - 1s 91ms/step - loss: 1.2279 - mae: 1.6375
# Epoch 49/50
# 7/7 [==============================] - 1s 90ms/step - loss: 1.2406 - mae: 1.6448
# Epoch 50/50
# 7/7 [==============================] - 1s 89ms/step - loss: 1.2223 - mae: 1.6249

# %% [markdown]
# Now see the results by geting predicitons and computing the metrics.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 4/4 [==============================] - 2s 27ms/step

# %%
# Compute the MAE
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 1.3879108

# %%
'''best achieved, do not change'''
# Out:
# 'best achieved, do not change'
